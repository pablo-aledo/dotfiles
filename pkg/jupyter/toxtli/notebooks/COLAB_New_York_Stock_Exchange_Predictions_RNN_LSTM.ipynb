# %% [markdown]
# Adapted by Carlos Toxtli http://www.carlostoxtli.com/#colab-stock-2
#
# Credits: https://github.com/deadskull7/New-York-Stock-Exchange-Predictions-RNN-LSTM/

# %%
# !mkdir input
# !gdown -O prices.zip https://drive.google.com/uc?id=1MGtfXBMSXHAQodByEYcdA0NeKMPWugf9
# !unzip prices.zip
# !mv *.csv input/
# !git clone https://github.com/deadskull7/New-York-Stock-Exchange-Predictions-RNN-LSTM.git
# %cd New-York-Stock-Exchange-Predictions-RNN-LSTM
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1MGtfXBMSXHAQodByEYcdA0NeKMPWugf9
# To: /content/prices.zip
# 31.8MB [00:00, 39.0MB/s]
# Archive:  prices.zip
#   inflating: prices-split-adjusted.csv
#    creating: __MACOSX/
#   inflating: __MACOSX/._prices-split-adjusted.csv
#   inflating: fundamentals.csv
#   inflating: __MACOSX/._fundamentals.csv
#   inflating: prices.csv
#   inflating: __MACOSX/._prices.csv
#   inflating: securities.csv
#   inflating: __MACOSX/._securities.csv
# Cloning into 'New-York-Stock-Exchange-Predictions-RNN-LSTM'...
# remote: Enumerating objects: 77, done.
# remote: Total 77 (delta 0), reused 0 (delta 0), pack-reused 77
# Unpacking objects: 100% (77/77), done.
# /content/New-York-Stock-Exchange-Predictions-RNN-LSTM

# %% [markdown]
# # New York Stock Exhange Predictions RNN-LSTM

# %% [markdown]
# **Best on Kaggle.**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
print(os.listdir("../input"))
# Out:
# ['prices-split-adjusted.csv', 'securities.csv', 'fundamentals.csv', 'prices.csv']

# %%
df =  pd.read_csv('../input/prices.csv', header=0)
df.head()
# Out:
#                   date symbol        open  ...         low        high     volume
# 0  2016-01-05 00:00:00   WLTW  123.430000  ...  122.309998  126.250000  2163600.0
# 1  2016-01-06 00:00:00   WLTW  125.239998  ...  119.940002  125.540001  2386400.0
# 2  2016-01-07 00:00:00   WLTW  116.379997  ...  114.930000  119.739998  2489500.0
# 3  2016-01-08 00:00:00   WLTW  115.480003  ...  113.500000  117.440002  2006300.0
# 4  2016-01-11 00:00:00   WLTW  117.010002  ...  114.089996  117.330002  1408600.0
#
# [5 rows x 7 columns]

# %%
print(df.shape)
# Out:
# (851264, 7)

# %%
df.symbol.unique()[0:20]
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN'], dtype=object)

# %%
print(len(df.symbol.values))
# Out:
# 851264

# %%
df.describe()
# Out:
#                 open          close            low           high        volume
# count  851264.000000  851264.000000  851264.000000  851264.000000  8.512640e+05
# mean       70.836986      70.857109      70.118414      71.543476  5.415113e+06
# std        83.695876      83.689686      82.877294      84.465504  1.249468e+07
# min         0.850000       0.860000       0.830000       0.880000  0.000000e+00
# 25%        33.840000      33.849998      33.480000      34.189999  1.221500e+06
# 50%        52.770000      52.799999      52.230000      53.310001  2.476250e+06
# 75%        79.879997      79.889999      79.110001      80.610001  5.222500e+06
# max      1584.439941    1578.130005    1549.939941    1600.930054  8.596434e+08

# %%
df.isnull().sum()
# Out:
# date      0
# symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64

# %%
df.date.unique()
# Out:
# array(['2016-01-05 00:00:00', '2016-01-06 00:00:00',
#        '2016-01-07 00:00:00', ..., '2016-12-28', '2016-12-29',
#        '2016-12-30'], dtype=object)

# %%
comp_info = pd.read_csv('../input/securities.csv')
comp_info.head()
# Out:
#   Ticker symbol             Security  ... Date first added      CIK
# 0           MMM           3M Company  ...              NaN    66740
# 1           ABT  Abbott Laboratories  ...       1964-03-31     1800
# 2          ABBV               AbbVie  ...       2012-12-31  1551152
# 3           ACN        Accenture plc  ...       2011-07-06  1467373
# 4          ATVI  Activision Blizzard  ...       2015-08-31   718877
#
# [5 rows x 8 columns]

# %%
comp_info["Ticker symbol"].nunique()
# Out:
# 505

# %%
comp_info.loc[comp_info.Security.str.startswith('Face') , :]
# Out:
#     Ticker symbol  Security  ... Date first added      CIK
# 181            FB  Facebook  ...       2013-12-23  1326801
#
# [1 rows x 8 columns]

# %% [markdown]
# **Selecting any 6 companies using above method for visualizations on respective opening and closing stock prices.**

# %%
comp_plot = comp_info.loc[(comp_info["Security"] == 'Yahoo Inc.') | (comp_info["Security"] == 'Xerox Corp.') | (comp_info["Security"] == 'Adobe Systems Inc')
              | (comp_info["Security"] == 'Microsoft Corp.') | (comp_info["Security"] == 'Adobe Systems Inc') 
              | (comp_info["Security"] == 'Facebook') | (comp_info["Security"] == 'Goldman Sachs Group') , ["Ticker symbol"] ]["Ticker symbol"] 
print(comp_plot)
# Out:
# 6      ADBE
# 181      FB
# 212      GS
# 306    MSFT
# 496     XRX
# 500    YHOO
# Name: Ticker symbol, dtype: object

# %% [markdown]
# **Some companies and their opening and closing stock prices.**
# **Note: The differences is marginal , you might take open and close same but they are actually different after looking carefully.**

# %%
def plotter(code):
    global closing_stock
    global opening_stock
    f, axs = plt.subplots(2,2,figsize=(8,8))
    plt.subplot(212)
    company = df[df['symbol']==code]
    company = company.open.values.astype('float32')
    company = company.reshape(-1, 1)
    opening_stock = company
    plt.grid(True)
    plt.xlabel('Time')
    plt.ylabel(code + " open stock prices")
    plt.title('prices Vs Time')
    plt.plot(company , 'g')
    
    plt.subplot(211)
    company_close = df[df['symbol']==code]
    company_close = company_close.close.values.astype('float32')
    company_close = company_close.reshape(-1, 1)
    closing_stock = company_close
    plt.xlabel('Time')
    plt.ylabel(code + " close stock prices")
    plt.title('prices Vs Time')
    plt.grid(True)
    plt.plot(company_close , 'b')
    plt.show()
for i in comp_plot:
    plotter(i)

# %% [markdown]
# **Lets take a single stock as a sample to forecast further stock prices.**

# %%
closing_stock[: , 0]
# Out:
# array([17.1 , 17.23, 17.17, ..., 38.73, 38.64, 38.67], dtype=float32)

# %%
stocks = closing_stock[: , 0]
print(stocks)
stocks = stocks.reshape(len(stocks) , 1)
# Out:
# [17.1  17.23 17.17 ... 38.73 38.64 38.67]

# %% [markdown]
# **Feature scaling the vector for better model performance.**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
stocks = scaler.fit_transform(stocks)

# %%
train = int(len(stocks) * 0.80)
test = len(stocks) - train

# %%
print(train , test)
# Out:
# 1409 353

# %%
train = stocks[0:train]
print(train)
# Out:
# [[0.14559111]
#  [0.14874032]
#  [0.14728683]
#  ...
#  [0.63372093]
#  [0.6145833 ]
#  [0.6196705 ]]

# %%
test = stocks[len(train) : ]

# %%
train = train.reshape(len(train) , 1)
test = test.reshape(len(test) , 1)

# %%
print(train.shape , test.shape)
# Out:
# (1409, 1) (353, 1)

# %% [markdown]
# **process_data for the required input for LSTM.**

# %%
def process_data(data , n_features):
    dataX, dataY = [], []
    for i in range(len(data)-n_features-1):
        a = data[i:(i+n_features), 0]
        dataX.append(a)
        dataY.append(data[i + n_features, 0])
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# **Here I am taking 2 past values to predict a single value. This has already been checked and optimized after taking several cases.**

# %%
n_features = 2

trainX, trainY = process_data(train, n_features)
testX, testY = process_data(test, n_features)

# %%
print(trainX.shape , trainY.shape , testX.shape , testY.shape)
# Out:
# (1406, 2) (1406,) (350, 2) (350,)

# %% [markdown]
# **Reshaping again for required LSTM input as (sample , timestamp , features per sample).**

# %% [markdown]
# **Here I am taking timestamp as 1.**

# %%
trainX = trainX.reshape(trainX.shape[0] , 1 ,trainX.shape[1])
testX = testX.reshape(testX.shape[0] , 1 ,testX.shape[1])

# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense , BatchNormalization , Dropout , Activation
from keras.layers import LSTM , GRU
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.optimizers import Adam , SGD , RMSprop
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Checkpointing the model when required and using other callbacks.**

# %%
filepath="stock_weights.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='max')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1335: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %% [markdown]
# ## My personal tuned architecture for best performance on kaggle till date.

# %% [markdown]
# **The learning rate has been tuned for several times and so is the batch_size and the neurons in the layers.**

# %%
model = Sequential()
model.add(GRU(256 , input_shape = (1 , n_features) , return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(256))
model.add(Dropout(0.4))
model.add(Dense(64 ,  activation = 'relu'))
model.add(Dense(1))
print(model.summary())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 1, 256)            198912
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 740,737
# Trainable params: 740,737
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error', optimizer=Adam(lr = 0.0005) , metrics = ['mean_squared_error'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(trainX, trainY, epochs=100 , batch_size = 128 , 
          callbacks = [checkpoint , lr_reduce] , validation_data = (testX,testY))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 1406 samples, validate on 350 samples
# Epoch 1/100
# 1406/1406 [==============================] - 6s 4ms/step - loss: 0.1388 - mean_squared_error: 0.1388 - val_loss: 0.1491 - val_mean_squared_error: 0.1491
#
# Epoch 00001: val_loss improved from -inf to 0.14911, saving model to stock_weights.hdf5
# Epoch 2/100
# 1406/1406 [==============================] - 0s 124us/step - loss: 0.0340 - mean_squared_error: 0.0340 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
#
# Epoch 00002: val_loss did not improve from 0.14911
# Epoch 3/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
#
# Epoch 00003: val_loss did not improve from 0.14911
# Epoch 4/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
#
# Epoch 00004: val_loss did not improve from 0.14911
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# Epoch 5/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
#
# Epoch 00005: val_loss did not improve from 0.14911
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# Epoch 6/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
#
# Epoch 00006: val_loss did not improve from 0.14911
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# Epoch 7/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
#
# Epoch 00007: val_loss did not improve from 0.14911
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 5.000000555810402e-08.
# Epoch 8/100
# 1406/1406 [==============================] - 0s 124us/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00008: val_loss did not improve from 0.14911
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-09.
# Epoch 9/100
# 1406/1406 [==============================] - 0s 108us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00009: val_loss did not improve from 0.14911
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-10.
# Epoch 10/100
# 1406/1406 [==============================] - 0s 109us/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00010: val_loss did not improve from 0.14911
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-11.
# Epoch 11/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00011: val_loss did not improve from 0.14911
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-12.
# Epoch 12/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00012: val_loss did not improve from 0.14911
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-13.
# Epoch 13/100
# 1406/1406 [==============================] - 0s 112us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00013: val_loss did not improve from 0.14911
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 5.0000005221220725e-14.
# Epoch 14/100
# 1406/1406 [==============================] - 0s 117us/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00014: val_loss did not improve from 0.14911
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 5.000000589884709e-15.
# Epoch 15/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00015: val_loss did not improve from 0.14911
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 5.000000759291298e-16.
# Epoch 16/100
# 1406/1406 [==============================] - 0s 107us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00016: val_loss did not improve from 0.14911
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 5.000000547533061e-17.
# Epoch 17/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00017: val_loss did not improve from 0.14911
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 5.000000415184163e-18.
# Epoch 18/100
# 1406/1406 [==============================] - 0s 109us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00018: val_loss did not improve from 0.14911
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 5.000000332466102e-19.
# Epoch 19/100
# 1406/1406 [==============================] - 0s 112us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00019: val_loss did not improve from 0.14911
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 5.000000229068525e-20.
# Epoch 20/100
# 1406/1406 [==============================] - 0s 112us/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00020: val_loss did not improve from 0.14911
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 5.00000016444504e-21.
# Epoch 21/100
# 1406/1406 [==============================] - 0s 116us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00021: val_loss did not improve from 0.14911
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 5.000000245224397e-22.
# Epoch 22/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00022: val_loss did not improve from 0.14911
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 5.0000003461985925e-23.
# Epoch 23/100
# 1406/1406 [==============================] - 0s 107us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00023: val_loss did not improve from 0.14911
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5.000000472416337e-24.
# Epoch 24/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00024: val_loss did not improve from 0.14911
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 5.000000393530247e-25.
# Epoch 25/100
# 1406/1406 [==============================] - 0s 112us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00025: val_loss did not improve from 0.14911
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 5.000000590745473e-26.
# Epoch 26/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00026: val_loss did not improve from 0.14911
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 5.000000714004989e-27.
# Epoch 27/100
# 1406/1406 [==============================] - 0s 120us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00027: val_loss did not improve from 0.14911
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 5.00000071400499e-28.
# Epoch 28/100
# 1406/1406 [==============================] - 0s 109us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00028: val_loss did not improve from 0.14911
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 5.000000617708492e-29.
# Epoch 29/100
# 1406/1406 [==============================] - 0s 107us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00029: val_loss did not improve from 0.14911
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 5.0000006177084924e-30.
# Epoch 30/100
# 1406/1406 [==============================] - 0s 116us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00030: val_loss did not improve from 0.14911
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 5.0000007681717695e-31.
# Epoch 31/100
# 1406/1406 [==============================] - 0s 112us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00031: val_loss did not improve from 0.14911
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 5.000000956250865e-32.
# Epoch 32/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00032: val_loss did not improve from 0.14911
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 5.0000010738003005e-33.
# Epoch 33/100
# 1406/1406 [==============================] - 0s 115us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00033: val_loss did not improve from 0.14911
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 5.000001220737094e-34.
# Epoch 34/100
# 1406/1406 [==============================] - 0s 107us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00034: val_loss did not improve from 0.14911
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 5.000001037066102e-35.
# Epoch 35/100
# 1406/1406 [==============================] - 0s 115us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00035: val_loss did not improve from 0.14911
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-36.
# Epoch 36/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00036: val_loss did not improve from 0.14911
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-37.
# Epoch 37/100
# 1406/1406 [==============================] - 0s 108us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00037: val_loss did not improve from 0.14911
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 5.000000628111158e-38.
# Epoch 38/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00038: val_loss did not improve from 0.14911
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 5.000000516007281e-39.
# Epoch 39/100
# 1406/1406 [==============================] - 0s 109us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00039: val_loss did not improve from 0.14911
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 5.000001076526666e-40.
# Epoch 40/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00040: val_loss did not improve from 0.14911
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 5.000001076526667e-41.
# Epoch 41/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00041: val_loss did not improve from 0.14911
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 4.99997305055738e-42.
# Epoch 42/100
# 1406/1406 [==============================] - 0s 119us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00042: val_loss did not improve from 0.14911
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 4.9998329207109475e-43.
# Epoch 43/100
# 1406/1406 [==============================] - 0s 108us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00043: val_loss did not improve from 0.14911
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 5.002635517639597e-44.
# Epoch 44/100
# 1406/1406 [==============================] - 0s 116us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00044: val_loss did not improve from 0.14911
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 5.0446744715693416e-45.
# Epoch 45/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00045: val_loss did not improve from 0.14911
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 5.6051938572992686e-46.
# Epoch 46/100
# 1406/1406 [==============================] - 0s 121us/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00046: val_loss did not improve from 0.14911
# Epoch 47/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00047: val_loss did not improve from 0.14911
# Epoch 48/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00048: val_loss did not improve from 0.14911
# Epoch 49/100
# 1406/1406 [==============================] - 0s 115us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00049: val_loss did not improve from 0.14911
# Epoch 50/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00050: val_loss did not improve from 0.14911
# Epoch 51/100
# 1406/1406 [==============================] - 0s 119us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00051: val_loss did not improve from 0.14911
# Epoch 52/100
# 1406/1406 [==============================] - 0s 115us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00052: val_loss did not improve from 0.14911
# Epoch 53/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00053: val_loss did not improve from 0.14911
# Epoch 54/100
# 1406/1406 [==============================] - 0s 112us/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00054: val_loss did not improve from 0.14911
# Epoch 55/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00055: val_loss did not improve from 0.14911
# Epoch 56/100
# 1406/1406 [==============================] - 0s 109us/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00056: val_loss did not improve from 0.14911
# Epoch 57/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00057: val_loss did not improve from 0.14911
# Epoch 58/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00058: val_loss did not improve from 0.14911
# Epoch 59/100
# 1406/1406 [==============================] - 0s 107us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00059: val_loss did not improve from 0.14911
# Epoch 60/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00060: val_loss did not improve from 0.14911
# Epoch 61/100
# 1406/1406 [==============================] - 0s 112us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00061: val_loss did not improve from 0.14911
# Epoch 62/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00062: val_loss did not improve from 0.14911
# Epoch 63/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00063: val_loss did not improve from 0.14911
# Epoch 64/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00064: val_loss did not improve from 0.14911
# Epoch 65/100
# 1406/1406 [==============================] - 0s 121us/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00065: val_loss did not improve from 0.14911
# Epoch 66/100
# 1406/1406 [==============================] - 0s 103us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00066: val_loss did not improve from 0.14911
# Epoch 67/100
# 1406/1406 [==============================] - 0s 104us/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00067: val_loss did not improve from 0.14911
# Epoch 68/100
# 1406/1406 [==============================] - 0s 109us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00068: val_loss did not improve from 0.14911
# Epoch 69/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00069: val_loss did not improve from 0.14911
# Epoch 70/100
# 1406/1406 [==============================] - 0s 108us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00070: val_loss did not improve from 0.14911
# Epoch 71/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00071: val_loss did not improve from 0.14911
# Epoch 72/100
# 1406/1406 [==============================] - 0s 108us/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00072: val_loss did not improve from 0.14911
# Epoch 73/100
# 1406/1406 [==============================] - 0s 109us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00073: val_loss did not improve from 0.14911
# Epoch 74/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00074: val_loss did not improve from 0.14911
# Epoch 75/100
# 1406/1406 [==============================] - 0s 114us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00075: val_loss did not improve from 0.14911
# Epoch 76/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00076: val_loss did not improve from 0.14911
# Epoch 77/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00077: val_loss did not improve from 0.14911
# Epoch 78/100
# 1406/1406 [==============================] - 0s 117us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00078: val_loss did not improve from 0.14911
# Epoch 79/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00079: val_loss did not improve from 0.14911
# Epoch 80/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00080: val_loss did not improve from 0.14911
# Epoch 81/100
# 1406/1406 [==============================] - 0s 115us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00081: val_loss did not improve from 0.14911
# Epoch 82/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00082: val_loss did not improve from 0.14911
# Epoch 83/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00083: val_loss did not improve from 0.14911
# Epoch 84/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00084: val_loss did not improve from 0.14911
# Epoch 85/100
# 1406/1406 [==============================] - 0s 124us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00085: val_loss did not improve from 0.14911
# Epoch 86/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00086: val_loss did not improve from 0.14911
# Epoch 87/100
# 1406/1406 [==============================] - 0s 109us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00087: val_loss did not improve from 0.14911
# Epoch 88/100
# 1406/1406 [==============================] - 0s 106us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00088: val_loss did not improve from 0.14911
# Epoch 89/100
# 1406/1406 [==============================] - 0s 105us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00089: val_loss did not improve from 0.14911
# Epoch 90/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00090: val_loss did not improve from 0.14911
# Epoch 91/100
# 1406/1406 [==============================] - 0s 108us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00091: val_loss did not improve from 0.14911
# Epoch 92/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00092: val_loss did not improve from 0.14911
# Epoch 93/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00093: val_loss did not improve from 0.14911
# Epoch 94/100
# 1406/1406 [==============================] - 0s 109us/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00094: val_loss did not improve from 0.14911
# Epoch 95/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00095: val_loss did not improve from 0.14911
# Epoch 96/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00096: val_loss did not improve from 0.14911
# Epoch 97/100
# 1406/1406 [==============================] - 0s 115us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00097: val_loss did not improve from 0.14911
# Epoch 98/100
# 1406/1406 [==============================] - 0s 110us/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00098: val_loss did not improve from 0.14911
# Epoch 99/100
# 1406/1406 [==============================] - 0s 113us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00099: val_loss did not improve from 0.14911
# Epoch 100/100
# 1406/1406 [==============================] - 0s 111us/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00100: val_loss did not improve from 0.14911

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('model mean squared error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## The score below is best on kaggle kernels till date.

# %% [markdown]
# ## The mean square error for validation set is 0.000328 which is very low and good as well.

# %%
def model_score(model, X_train, y_train, X_test, y_test):
    trainScore = model.evaluate(X_train, y_train, verbose=0)
    print('Train Score: %.5f MSE (%.2f RMSE)' % (trainScore[0], math.sqrt(trainScore[0])))
    testScore = model.evaluate(X_test, y_test, verbose=0)
    print('Test Score: %.5f MSE (%.2f RMSE)' % (testScore[0], math.sqrt(testScore[0])))
    return trainScore[0], testScore[0]

model_score(model, trainX, trainY , testX, testY)
# Out:
# Train Score: 0.00431 MSE (0.07 RMSE)
# Test Score: 0.00485 MSE (0.07 RMSE)
# (0.004309527835130405, 0.0048476602243525645)

# %% [markdown]
# **Inverse transforming the scaled vector earlier and checking for the error visually in the graph.**

# %%
pred = model.predict(testX)
pred = scaler.inverse_transform(pred)
pred[:10]
# Out:
# array([[33.884308],
#        [32.842667],
#        [32.80551 ],
#        [33.489437],
#        [33.555733],
#        [33.340195],
#        [32.984093],
#        [32.36248 ],
#        [31.481373],
#        [30.396593]], dtype=float32)

# %%
testY = testY.reshape(testY.shape[0] , 1)
testY = scaler.inverse_transform(testY)
testY[:10]
# Out:
# array([[34.49    ],
#        [35.93    ],
#        [36.24    ],
#        [36.1     ],
#        [35.69    ],
#        [35.19    ],
#        [34.1     ],
#        [32.93    ],
#        [31.31    ],
#        [31.739998]], dtype=float32)

# %% [markdown]
# ## The space between the predicted (red) and actual (blue) line is self explanatory for the model tuning and performance.

# %%
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(testY , 'b')
plt.plot(pred , 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices
