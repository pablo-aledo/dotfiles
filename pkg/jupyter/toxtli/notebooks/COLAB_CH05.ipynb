# %% [markdown]
# Adapted by Carlos Toxtli https://www.carlostoxtli.com/#colab-kmean-1
#
# Source: https://github.com/PacktPublishing/Artificial-Intelligence-By-Example-Second-Edition/tree/master/CH05

# %%
# !gdown https://drive.google.com/uc?id=1gTP1SZocvJGQsJPV2GZVoNcgs0Ze-56L
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gTP1SZocvJGQsJPV2GZVoNcgs0Ze-56L
# To: /content/data.csv
# 100% 34.8k/34.8k [00:00<00:00, 29.6MB/s]

# %% [markdown]
# Random sample

# %%
#K-means clustering with Mini-Batch
#Build with Sklearn
#Copyright 2018 Denis Rothman MIT License. See LICENSE.
from sklearn.cluster import KMeans  
import pandas as pd
from matplotlib import pyplot as plt
from random import randint
import numpy as np

#I.The training Dataset 
dataset = pd.read_csv('data.csv')
print(len(dataset))
print(dataset.head())
print(dataset)
'''Output of print(dataset)
      Distance  location
0           80        53
1           18         8
2           55        38
...
'''

n=1000
dataset1=np.zeros(shape=(n,2))

li=0
for i in range (n):
    j=randint(0,4998)
    dataset1[i][0]=dataset.iloc[j,0]
    dataset1[i][1]=dataset.iloc[j,1]
    

#II.Hyperparameters
# Features = 2 :implict through the shape of the dataset (2 columns)
k = 6
kmeans = KMeans(n_clusters=k)

#III.K-means clustering algorithm
kmeans = kmeans.fit(dataset1)        #Computing k-means clustering
gcenters = kmeans.cluster_centers_   # the geometric centers or centroids
print("The geometric centers or centroids:")
print(gcenters)

'''Ouput of centroid coordinates

The geometric centers or centroids:

Monte Carlo philosophy:

MC[[ 19.7877095   16.40782123]
  [ 21.38965517  15.04597701]]

MC [ 99.87603306  81.1322314 ]
   [ 96.06151645  84.57939914]

MC[ 31.29139073  72.64900662]]
  [ 32.12590799  54.84866828]

MC [ 61.54891304  49.875     ]
   [ 68.84578885  55.63226572]


MC [ 63.86206897  84.20689655]
   [ 45.24736842  23.65263158]


Complete dataset:

[[ 48.7986755   85.76688742]
 [ 48.44532803  24.4333996 ]
'''


#IV.Defining the Result labels 
labels = kmeans.labels_
colors = ['blue','red','green','black','yellow','brown','orange']


#V.Displaying the results : datapoints and clusters
y = 0
for x in labels:
    plt.scatter(dataset1[y,0], dataset1[y,1],color=colors[x])
    y+=1       
for x in range(k):
    lines = plt.plot(gcenters[x,0],gcenters[x,1],'kx')    

title = ('No of clusters (k) = {}').format(k)
plt.title(title)
plt.xlabel('Distance')
plt.ylabel('Location')
plt.show()

#VI.Test dataset and prediction
x_test = [[40.0,67],[20.0,61],[90.0,90],
          [50.0,54],[20.0,80],[90.0,60]]
prediction = kmeans.predict(x_test)
print("The predictions:")
print (prediction)
'''
Output of the cluster number of each example
[3 3 2 3 3 4]
'''
# Out:
# 4999
#    Distance  location
# 0        80        53
# 1        18         8
# 2        55        38
# 3        74        74
# 4        17         4
#       Distance  location
# 0           80        53
# 1           18         8
# 2           55        38
# 3           74        74
# 4           17         4
# 5          108       100
# 6           60        21
# 7           61        39
# 8           51        15
# 9           73        76
# 10          10         6
# 11          41        83
# 12          62        49
# 13          97        56
# 14          40        53
# 15          38        96
# 16          32        54
# 17          27        52
# 18          42        31
# 19          59        99
# 20          33        22
# 21          23        14
# 22          49        31
# 23          43        33
# 24          78        75
# 25          63        70
# 26          55        63
# 27          30        43
# 28          49         3
# 29          79        98
# ...        ...       ...
# 4969        44        62
# 4970        47        89
# 4971        51        12
# 4972        44        70
# 4973        86        94
# 4974        91        76
# 4975        36         9
# 4976        69        47
# 4977        39        32
# 4978        30        79
# 4979        71        36
# 4980       104        95
# 4981        71        48
# 4982        71        92
# 4983        49        32
# 4984        39        33
# 4985        19        77
# 4986        25        74
# 4987        21        79
# 4988        32        78
# 4989        82        64
# 4990       126        96
# 4991        61        85
# 4992        10        63
# 4993        96       100
# 4994        26        28
# 4995        50        91
# 4996        19        32
# 4997        73        95
# 4998        36        64
#
# [4999 rows x 2 columns]
# The geometric centers or centroids:
# [[102.56074766  82.56074766]
#  [ 47.40084388  33.27848101]
#  [ 62.10191083  84.64968153]
#  [ 68.33544304  53.93670886]
#  [ 26.53051643  13.95305164]
#  [ 29.59375     70.4453125 ]]
# The predictions:
# [5 5 0 3 5 3]
# '\nOutput of the cluster number of each example\n[3 3 2 3 3 4]\n'

# %% [markdown]
# Batch shuffling

# %%
#K-means clustering - Mini-Batch-Shuffling
#Build with Sklearn
#Copyright 2018 Denis Rothman MIT License. See LICENSE.
from sklearn.cluster import KMeans  
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.utils import shuffle
import numpy as np

#I.The training Dataset 
dataseti = pd.read_csv('data.csv')
print (dataseti.head())
print("initial order")
print(dataseti)

print("shuffled")
dataset=shuffle(dataseti, random_state=13)
print(dataset)

n=1000
dataset1=np.zeros(shape=(n,2))
for i in range (n):
    dataset1[i][0]=dataset.iloc[i,0]
    dataset1[i][1]=dataset.iloc[i,1]

print("shuffled selection")
print(dataset1)

#II.Hyperparameters
# Features = 2
k = 6
kmeans = KMeans(n_clusters=k)

#III.K-means clustering algorithm
kmeans = kmeans.fit(dataset1)         #Computing k-means clustering
gcenters = kmeans.cluster_centers_   # the geometric centers or centroids
print("The geometric centers or centroids:")
print(gcenters)

#IV.Defining the Result labels 
labels = kmeans.labels_
colors = ['blue','red','green','black','yellow','brown','orange']

#V.Displaying the results : datapoints and clusters
y = 0
for x in labels:
    plt.scatter(dataset1[y,0], dataset1[y,1],color=colors[x])
    y+=1       
for x in range(k):
    lines = plt.plot(gcenters[x,0],gcenters[x,1],'kx')    

title = ('No of clusters (k) = {}').format(k)
plt.title(title)
plt.xlabel('Distance')
plt.ylabel('Location')
plt.show()

#VI.Test dataset and prediction
x_test = [[40.0,67],[20.0,61],[90.0,90],
          [50.0,54],[20.0,80],[90.0,60]]
prediction = kmeans.predict(x_test)
print("The predictions:")
print (prediction)
# Out:
#    Distance  location
# 0        80        53
# 1        18         8
# 2        55        38
# 3        74        74
# 4        17         4
# initial order
#       Distance  location
# 0           80        53
# 1           18         8
# 2           55        38
# 3           74        74
# 4           17         4
# 5          108       100
# 6           60        21
# 7           61        39
# 8           51        15
# 9           73        76
# 10          10         6
# 11          41        83
# 12          62        49
# 13          97        56
# 14          40        53
# 15          38        96
# 16          32        54
# 17          27        52
# 18          42        31
# 19          59        99
# 20          33        22
# 21          23        14
# 22          49        31
# 23          43        33
# 24          78        75
# 25          63        70
# 26          55        63
# 27          30        43
# 28          49         3
# 29          79        98
# ...        ...       ...
# 4969        44        62
# 4970        47        89
# 4971        51        12
# 4972        44        70
# 4973        86        94
# 4974        91        76
# 4975        36         9
# 4976        69        47
# 4977        39        32
# 4978        30        79
# 4979        71        36
# 4980       104        95
# 4981        71        48
# 4982        71        92
# 4983        49        32
# 4984        39        33
# 4985        19        77
# 4986        25        74
# 4987        21        79
# 4988        32        78
# 4989        82        64
# 4990       126        96
# 4991        61        85
# 4992        10        63
# 4993        96       100
# 4994        26        28
# 4995        50        91
# 4996        19        32
# 4997        73        95
# 4998        36        64
#
# [4999 rows x 2 columns]
# shuffled
#       Distance  location
# 1552        39        14
# 658        125        89
# 1763        35        51
# 2272        60        40
# 1404        28        98
# 4991        61        85
# 4545        48        84
# 3019        33        50
# 2776        18        18
# 4563        64        44
# 2746       109        77
# 681         13        11
# 3392        64        73
# 3653        72        91
# 2837        56       100
# 4029        83        74
# 4444       106        72
# 4057        59        93
# 2493        50        75
# 4622        35        66
# 1516        43        86
# 1644        41        32
# 2331        36        29
# 3067        82        87
# 2292        40        16
# 1112        45        61
# 452         38        11
# 1319        42        63
# 1498        34         6
# 2667        17        58
# ...        ...       ...
# 389         63        74
# 3555        53        51
# 487         55        56
# 2421        37        61
# 2850        70        47
# 844          8         5
# 11          41        83
# 2460        76       100
# 2706        23        42
# 4097        75        59
# 75          39        23
# 1013        37        22
# 1427        42        67
# 2963        29         3
# 3232        23        41
# 3892        37        23
# 4939        53        37
# 1865        15        30
# 4045        55        37
# 2277        35        99
# 1462       102        97
# 1986        61        72
# 922         42        71
# 4026       114        96
# 748         11        74
# 153         31        66
# 866         66        45
# 2790        59        70
# 74          60        78
# 338         20         2
#
# [4999 rows x 2 columns]
# shuffled selection
# [[ 39.  14.]
#  [125.  89.]
#  [ 35.  51.]
#  ...
#  [ 35.  54.]
#  [ 60.  78.]
#  [ 48.  82.]]
# The geometric centers or centroids:
# [[47.59808612 22.91866029]
#  [51.79874214 85.72955975]
#  [99.67857143 84.90714286]
#  [29.85714286 53.33333333]
#  [20.11842105 13.86842105]
#  [65.56395349 53.88953488]]
# The predictions:
# [3 3 2 5 3 5]

# %% [markdown]
# K-means

# %%
#K-means clustering
#Build with Sklearn
#Copyright 2019 Denis Rothman MIT License. See LICENSE.

from sklearn.cluster import KMeans  
import pandas as pd
from matplotlib import pyplot as plt
import pickle


#I.The training Dataset 
dataset = pd.read_csv('data.csv')
print (dataset.head())
print(dataset)
'''Output of print(dataset)
      Distance  location
0           80        53
1           18         8
2           55        38
...
'''

#II.Hyperparameters
# Features = 2
k = 6
kmeans = KMeans(n_clusters=k)

#III.K-means clustering algorithm
kmeans = kmeans.fit(dataset)         #Computing k-means clustering
gcenters = kmeans.cluster_centers_   # the geometric centers or centroids
print("The geometric centers or centroids:")
print(gcenters)
'''Ouput of centroid coordinates
[[ 48.7986755   85.76688742]
 [ 32.12590799  54.84866828]
 [ 96.06151645  84.57939914]
 [ 68.84578885  55.63226572]
 [ 48.44532803  24.4333996 ]
 [ 21.38965517  15.04597701]]
'''


#IV.Defining the Result labels 
labels = kmeans.labels_
colors = ['blue','red','green','black','yellow','brown','orange']


#V.Displaying the results : datapoints and clusters
y = 0
for x in labels:
    plt.scatter(dataset.iloc[y,0], dataset.iloc[y,1],color=colors[x])
    y+=1       
for x in range(k):
    lines = plt.plot(gcenters[x,0],gcenters[x,1],'kx')    

title = ('No of clusters (k) = {}').format(k)
plt.title(title)
plt.xlabel('Distance')
plt.ylabel('Location')
plt.show()

#VI.Test dataset and prediction
x_test = [[40.0,67],[20.0,61],[90.0,90],
          [50.0,54],[20.0,80],[90.0,60]]
prediction = kmeans.predict(x_test)
print("The predictions:")
print (prediction)
'''
Output of the cluster number of each example
[3 3 2 3 3 4]
'''

# save model
filename="kmc_model.sav"
pickle.dump(kmeans, open(filename, 'wb'))
print("model saved")
# Out:
#    Distance  location
# 0        80        53
# 1        18         8
# 2        55        38
# 3        74        74
# 4        17         4
#       Distance  location
# 0           80        53
# 1           18         8
# 2           55        38
# 3           74        74
# 4           17         4
# 5          108       100
# 6           60        21
# 7           61        39
# 8           51        15
# 9           73        76
# 10          10         6
# 11          41        83
# 12          62        49
# 13          97        56
# 14          40        53
# 15          38        96
# 16          32        54
# 17          27        52
# 18          42        31
# 19          59        99
# 20          33        22
# 21          23        14
# 22          49        31
# 23          43        33
# 24          78        75
# 25          63        70
# 26          55        63
# 27          30        43
# 28          49         3
# 29          79        98
# ...        ...       ...
# 4969        44        62
# 4970        47        89
# 4971        51        12
# 4972        44        70
# 4973        86        94
# 4974        91        76
# 4975        36         9
# 4976        69        47
# 4977        39        32
# 4978        30        79
# 4979        71        36
# 4980       104        95
# 4981        71        48
# 4982        71        92
# 4983        49        32
# 4984        39        33
# 4985        19        77
# 4986        25        74
# 4987        21        79
# 4988        32        78
# 4989        82        64
# 4990       126        96
# 4991        61        85
# 4992        10        63
# 4993        96       100
# 4994        26        28
# 4995        50        91
# 4996        19        32
# 4997        73        95
# 4998        36        64
#
# [4999 rows x 2 columns]
# The geometric centers or centroids:
# [[21.35023041 15.05875576]
#  [95.9957204  84.56348074]
#  [48.42559524 24.40376984]
#  [48.7986755  85.76688742]
#  [68.83590963 55.57669441]
#  [32.12590799 54.84866828]]
# The predictions:
# [5 5 1 5 5 4]
# model saved

# %% [markdown]
# Chaining 1

# %%
#Chaining a K-means clustering algorithm to a Decision Tree
#Copyright 2019 Denis Rothman MIT License. See LICENSE.
from sklearn.cluster import KMeans  
import pandas as pd
from matplotlib import pyplot as plt
import pickle
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn import metrics 

#----- chained K-means clustering and Decision Tree  
#I.KMC. The prediction dataset and model 
dataset = pd.read_csv('data.csv')
kmeans = pickle.load(open('kmc_model.sav', 'rb'))
   
#saveing the predictions
kmcpred=np.zeros((1000, 3)) 
predict=1
if predict==1:
    for i in range(0,1000):
        xf1=dataset.at[i,'Distance'];xf2=dataset.at[i,'location'];
        X_DL = [[xf1,xf2]]
        prediction = kmeans.predict(X_DL)
        #print (i+1,"The prediction for",X_DL," is:",str(prediction).strip('[]'))
        #print (i+1,"The prediction for",str(X_DL).strip('[]')," is:",str(prediction).strip('[]'))
        p=str(prediction).strip('[]')
        p=int(p)
        kmcpred[i][0]=int(xf1);kmcpred[i][1]=int(xf2);kmcpred[i][2]=p;
np.savetxt('ckmc.csv', kmcpred, delimiter=',', fmt='%d')

# %% [markdown]
# Decission tree

# %%
# -*- coding: utf-8 -*-
# Decision Tree Classifier
# Copyright 2019 Denis Rothman MIT License. See LICENSE in GitHub directory.
import pandas as pd #data processing
from sklearn.tree import DecisionTreeClassifier #the dt classifier
from sklearn.model_selection import train_test_split  #split the data into training data and testing data
from sklearn import metrics #measure prediction performance  
import pickle #save and load estimator models

#loading dataset
col_names = ['f1', 'f2','label']
df = pd.read_csv("ckmc.csv", header=None, names=col_names)

print(df.head())

#defining features and label (classes)
feature_cols = ['f1', 'f2']
X = df[feature_cols] # Features
y = df.label # Target variable

print(X)

print(y)

# splitting df (dataset) into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# create the decision tree classifier
dtc = DecisionTreeClassifier()

# train the decision tree
dtc = dtc.fit(X_train,y_train)

#predictions on X_test
print("prediction")
y_pred = dtc.predict(X_test)
print(y_pred)

# model accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

#save model
pickle.dump(dtc, open("dt.sav", 'wb'))


#Uncomment this part of the code to generate a graph and png
#    set graph=1 to activate the function, graph=0 to deactivate the function
from sklearn import tree
import pydotplus
from IPython.display import Image


# Creating the graph and exporting it
dot_data = tree.export_graphviz(dtc, out_file=None, 
                                filled=True, rounded=True,
                                feature_names=feature_cols,  
                                class_names=['0','1','2','3','4','5'])

#creating graph 
graph = pydotplus.graph_from_dot_data(dot_data)  

#save graph
image=graph.create_png()
graph.write_png("kmc_dt.png")
Image(filename="kmc_dt.png")
# Out:
#    f1  f2  label
# 0  80  53      4
# 1  18   8      0
# 2  55  38      2
# 3  74  74      4
# 4  17   4      0
#       f1   f2
# 0     80   53
# 1     18    8
# 2     55   38
# 3     74   74
# 4     17    4
# 5    108  100
# 6     60   21
# 7     61   39
# 8     51   15
# 9     73   76
# 10    10    6
# 11    41   83
# 12    62   49
# 13    97   56
# 14    40   53
# 15    38   96
# 16    32   54
# 17    27   52
# 18    42   31
# 19    59   99
# 20    33   22
# 21    23   14
# 22    49   31
# 23    43   33
# 24    78   75
# 25    63   70
# 26    55   63
# 27    30   43
# 28    49    3
# 29    79   98
# ..   ...  ...
# 970   68   41
# 971   67   89
# 972   79   79
# 973   39   24
# 974   47   48
# 975  115   88
# 976   79   82
# 977   19   33
# 978   76   86
# 979   82   82
# 980   23   51
# 981   45   66
# 982   66   69
# 983   18   69
# 984   25   88
# 985   47   61
# 986   92  100
# 987   53   24
# 988   24    8
# 989   61   86
# 990    8   31
# 991   37   11
# 992   57   44
# 993   41   93
# 994   85   79
# 995  103  100
# 996   71   82
# 997   50   44
# 998   62   51
# 999   67   49
#
# [1000 rows x 2 columns]
# 0      4
# 1      0
# 2      2
# 3      4
# 4      0
# 5      1
# 6      2
# 7      4
# 8      2
# 9      4
# 10     0
# 11     3
# 12     4
# 13     4
# 14     5
# 15     3
# 16     5
# 17     5
# 18     2
# 19     3
# 20     0
# 21     0
# 22     2
# 23     2
# 24     1
# 25     4
# 26     4
# 27     5
# 28     2
# 29     1
#       ..
# 970    4
# 971    3
# 972    1
# 973    2
# 974    5
# 975    1
# 976    1
# 977    0
# 978    1
# 979    1
# 980    5
# 981    5
# 982    4
# 983    5
# 984    3
# 985    5
# 986    1
# 987    2
# 988    0
# 989    3
# 990    0
# 991    0
# 992    4
# 993    3
# 994    1
# 995    1
# 996    3
# 997    2
# 998    4
# 999    4
# Name: label, Length: 1000, dtype: int64
# prediction
# [1 0 2 4 2 1 4 2 1 2 1 2 4 0 3 0 0 2 5 5 2 0 5 5 0 2 4 1 3 2 4 5 4 5 0 3 2
#  0 2 0 5 2 4 4 5 3 4 3 5 1 5 3 3 0 2 5 5 5 1 3 0 1 2 4 5 1 3 1 1 5 2 2 4 3
#  2 4 4 3 0 1 1 1 1 3 4 4 1 0 5 4 5 4 4 1 3 5 1 4 1 4 3 4 2 2 2 1 3 5 4 0 2
#  2 3 2 3 3 0 4 1 2 2 1 1 3 3 1 3 3 3 1 1 1 0 2 2 2 4 1 2 5 3 5 2 0 0 3 3 4
#  5 4 5 4 2 0 4 4 3 3 1 4 2 2 5 4 3 2 5 2 0 2 2 2 5 3 0 5 5 2 2 2 5 0 4 0 0
#  0 0 4 2 5 2 3 2 0 5 3 3 5 3 5 2 1 4 0 2 3 3 4 0 0 3 2 3 3 2 1 0 3 0 0 4 4
#  0 3 5 0 2 2 0 4 0 4 0 3 2 1 1 3 3 4 2 2 4 3 0 1 3 5 0 2 4 4 1 1 4 2 5 3 0
#  3 2 1 1 5 3 5 4 1 2 3 5 2 2 2 2 1 3 0 2 5 5 4 3 2 1 1 5 2 5 5 0 5 1 5 0 2
#  1 5 0 0]
# Accuracy: 0.9733333333333334

# %% [markdown]
# KMC Chainning

# %%
#II.Decison Tree.
adt=1 #activate decision tree or not
if adt==1:
    #I.DT. The prediction dataset and model 
    col_names = ['f1', 'f2','label']
    # load dataset
    ds = pd.read_csv('ckmc.csv', header=None, names=col_names)

    #split dataset in features and target variable
    feature_cols = ['f1', 'f2']
    X = ds[feature_cols] # Features
    y = ds.label # Target variable

    # Split dataset into training set and test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

    # Load model
    dt = pickle.load(open('dt.sav', 'rb'))

    #Predict the response for test dataset
    y_pred = dt.predict(X_test)

    # Model Accuracy
    acc=metrics.accuracy_score(y_test, y_pred)
    print("Accuracy:",round(acc,3))


    #Double Check the Model's Accuracy
    doublecheck=1 #0 deactivated, 1 activated 
    if doublecheck==1:
        t=0
        f=0
        for i in range(0,1000):
            xf1=ds.at[i,'f1'];xf2=ds.at[i,'f2'];xclass=ds.at[i,'label']
            X_DL = [[xf1,xf2]]
            prediction =dt.predict(X_DL)
            e=False
            if(prediction==xclass):
                e=True
                t+=1
            if(prediction!=xclass):
                e=False
                f+=1
            print (i+1,"The prediction for",X_DL," is:",str(prediction).strip('[]'),"the class is",xclass,"acc.:",e)

        print("true:",t,"false",f,"accuracy",round(t/(t+f),3))
# Out:
# Accuracy: 0.973
# 1 The prediction for [[80, 53]]  is: 1 the class is 1 acc.: True
# 2 The prediction for [[18, 8]]  is: 0 the class is 0 acc.: True
# 3 The prediction for [[55, 38]]  is: 3 the class is 3 acc.: True
# 4 The prediction for [[74, 74]]  is: 2 the class is 1 acc.: False
# 5 The prediction for [[17, 4]]  is: 0 the class is 0 acc.: True
# 6 The prediction for [[108, 100]]  is: 2 the class is 2 acc.: True
# 7 The prediction for [[60, 21]]  is: 3 the class is 3 acc.: True
# 8 The prediction for [[61, 39]]  is: 1 the class is 1 acc.: True
# 9 The prediction for [[51, 15]]  is: 3 the class is 3 acc.: True
# 10 The prediction for [[73, 76]]  is: 1 the class is 1 acc.: True
# 11 The prediction for [[10, 6]]  is: 0 the class is 0 acc.: True
# 12 The prediction for [[41, 83]]  is: 4 the class is 4 acc.: True
# 13 The prediction for [[62, 49]]  is: 1 the class is 1 acc.: True
# 14 The prediction for [[97, 56]]  is: 1 the class is 1 acc.: True
# 15 The prediction for [[40, 53]]  is: 5 the class is 5 acc.: True
# 16 The prediction for [[38, 96]]  is: 4 the class is 4 acc.: True
# 17 The prediction for [[32, 54]]  is: 5 the class is 5 acc.: True
# 18 The prediction for [[27, 52]]  is: 5 the class is 5 acc.: True
# 19 The prediction for [[42, 31]]  is: 3 the class is 3 acc.: True
# 20 The prediction for [[59, 99]]  is: 4 the class is 4 acc.: True
# 21 The prediction for [[33, 22]]  is: 0 the class is 0 acc.: True
# 22 The prediction for [[23, 14]]  is: 0 the class is 0 acc.: True
# 23 The prediction for [[49, 31]]  is: 3 the class is 3 acc.: True
# 24 The prediction for [[43, 33]]  is: 3 the class is 3 acc.: True
# 25 The prediction for [[78, 75]]  is: 2 the class is 2 acc.: True
# 26 The prediction for [[63, 70]]  is: 1 the class is 1 acc.: True
# 27 The prediction for [[55, 63]]  is: 1 the class is 1 acc.: True
# 28 The prediction for [[30, 43]]  is: 5 the class is 5 acc.: True
# 29 The prediction for [[49, 3]]  is: 3 the class is 3 acc.: True
# 30 The prediction for [[79, 98]]  is: 2 the class is 2 acc.: True
# 31 The prediction for [[65, 37]]  is: 1 the class is 1 acc.: True
# 32 The prediction for [[7, 4]]  is: 0 the class is 0 acc.: True
# 33 The prediction for [[51, 1]]  is: 3 the class is 3 acc.: True
# 34 The prediction for [[28, 8]]  is: 0 the class is 0 acc.: True
# 35 The prediction for [[50, 82]]  is: 4 the class is 4 acc.: True
# 36 The prediction for [[18, 9]]  is: 0 the class is 0 acc.: True
# 37 The prediction for [[43, 15]]  is: 3 the class is 3 acc.: True
# 38 The prediction for [[21, 10]]  is: 0 the class is 0 acc.: True
# 39 The prediction for [[34, 98]]  is: 4 the class is 4 acc.: True
# 40 The prediction for [[29, 67]]  is: 5 the class is 5 acc.: True
# 41 The prediction for [[92, 56]]  is: 1 the class is 1 acc.: True
# 42 The prediction for [[61, 83]]  is: 4 the class is 4 acc.: True
# 43 The prediction for [[34, 31]]  is: 3 the class is 3 acc.: True
# 44 The prediction for [[91, 72]]  is: 2 the class is 2 acc.: True
# 45 The prediction for [[24, 64]]  is: 5 the class is 5 acc.: True
# 46 The prediction for [[46, 43]]  is: 5 the class is 5 acc.: True
# 47 The prediction for [[44, 10]]  is: 3 the class is 3 acc.: True
# 48 The prediction for [[25, 26]]  is: 0 the class is 0 acc.: True
# 49 The prediction for [[30, 25]]  is: 0 the class is 0 acc.: True
# 50 The prediction for [[44, 12]]  is: 3 the class is 3 acc.: True
# 51 The prediction for [[20, 14]]  is: 0 the class is 0 acc.: True
# 52 The prediction for [[88, 68]]  is: 2 the class is 2 acc.: True
# 53 The prediction for [[8, 3]]  is: 0 the class is 0 acc.: True
# 54 The prediction for [[51, 71]]  is: 4 the class is 4 acc.: True
# 55 The prediction for [[42, 7]]  is: 3 the class is 3 acc.: True
# 56 The prediction for [[99, 66]]  is: 2 the class is 2 acc.: True
# 57 The prediction for [[78, 59]]  is: 1 the class is 1 acc.: True
# 58 The prediction for [[45, 5]]  is: 3 the class is 3 acc.: True
# 59 The prediction for [[37, 55]]  is: 5 the class is 5 acc.: True
# 60 The prediction for [[52, 21]]  is: 3 the class is 3 acc.: True
# 61 The prediction for [[19, 9]]  is: 0 the class is 0 acc.: True
# 62 The prediction for [[38, 50]]  is: 5 the class is 5 acc.: True
# 63 The prediction for [[97, 83]]  is: 2 the class is 2 acc.: True
# 64 The prediction for [[69, 49]]  is: 1 the class is 1 acc.: True
# 65 The prediction for [[97, 96]]  is: 2 the class is 2 acc.: True
# 66 The prediction for [[80, 40]]  is: 1 the class is 1 acc.: True
# 67 The prediction for [[20, 30]]  is: 0 the class is 0 acc.: True
# 68 The prediction for [[53, 37]]  is: 3 the class is 3 acc.: True
# 69 The prediction for [[44, 22]]  is: 3 the class is 3 acc.: True
# 70 The prediction for [[49, 22]]  is: 3 the class is 3 acc.: True
# 71 The prediction for [[28, 12]]  is: 0 the class is 0 acc.: True
# 72 The prediction for [[40, 29]]  is: 3 the class is 3 acc.: True
# 73 The prediction for [[57, 71]]  is: 4 the class is 4 acc.: True
# 74 The prediction for [[58, 72]]  is: 4 the class is 4 acc.: True
# 75 The prediction for [[60, 78]]  is: 4 the class is 4 acc.: True
# 76 The prediction for [[39, 23]]  is: 3 the class is 3 acc.: True
# 77 The prediction for [[50, 18]]  is: 3 the class is 3 acc.: True
# 78 The prediction for [[5, 13]]  is: 0 the class is 0 acc.: True
# 79 The prediction for [[61, 32]]  is: 3 the class is 3 acc.: True
# 80 The prediction for [[37, 11]]  is: 0 the class is 0 acc.: True
# 81 The prediction for [[74, 86]]  is: 2 the class is 2 acc.: True
# 82 The prediction for [[47, 17]]  is: 3 the class is 3 acc.: True
# 83 The prediction for [[28, 21]]  is: 0 the class is 0 acc.: True
# 84 The prediction for [[70, 88]]  is: 4 the class is 4 acc.: True
# 85 The prediction for [[119, 86]]  is: 2 the class is 2 acc.: True
# 86 The prediction for [[43, 37]]  is: 3 the class is 3 acc.: True
# 87 The prediction for [[43, 54]]  is: 5 the class is 5 acc.: True
# 88 The prediction for [[34, 89]]  is: 4 the class is 4 acc.: True
# 89 The prediction for [[25, 58]]  is: 5 the class is 5 acc.: True
# 90 The prediction for [[70, 71]]  is: 1 the class is 1 acc.: True
# 91 The prediction for [[76, 62]]  is: 1 the class is 1 acc.: True
# 92 The prediction for [[75, 97]]  is: 2 the class is 2 acc.: True
# 93 The prediction for [[56, 43]]  is: 1 the class is 1 acc.: True
# 94 The prediction for [[59, 41]]  is: 1 the class is 1 acc.: True
# 95 The prediction for [[29, 37]]  is: 5 the class is 5 acc.: True
# 96 The prediction for [[46, 43]]  is: 5 the class is 5 acc.: True
# 97 The prediction for [[35, 23]]  is: 3 the class is 3 acc.: True
# 98 The prediction for [[43, 12]]  is: 3 the class is 3 acc.: True
# 99 The prediction for [[63, 37]]  is: 3 the class is 3 acc.: True
# 100 The prediction for [[21, 15]]  is: 0 the class is 0 acc.: True
# 101 The prediction for [[21, 32]]  is: 0 the class is 0 acc.: True
# 102 The prediction for [[75, 31]]  is: 1 the class is 1 acc.: True
# 103 The prediction for [[40, 58]]  is: 5 the class is 5 acc.: True
# 104 The prediction for [[19, 10]]  is: 0 the class is 0 acc.: True
# 105 The prediction for [[8, 8]]  is: 0 the class is 0 acc.: True
# 106 The prediction for [[64, 78]]  is: 4 the class is 4 acc.: True
# 107 The prediction for [[42, 82]]  is: 4 the class is 4 acc.: True
# 108 The prediction for [[48, 36]]  is: 3 the class is 3 acc.: True
# 109 The prediction for [[61, 55]]  is: 1 the class is 1 acc.: True
# 110 The prediction for [[48, 68]]  is: 4 the class is 4 acc.: True
# 111 The prediction for [[55, 26]]  is: 3 the class is 3 acc.: True
# 112 The prediction for [[10, 13]]  is: 0 the class is 0 acc.: True
# 113 The prediction for [[89, 51]]  is: 1 the class is 1 acc.: True
# 114 The prediction for [[32, 64]]  is: 5 the class is 5 acc.: True
# 115 The prediction for [[33, 78]]  is: 4 the class is 4 acc.: True
# 116 The prediction for [[35, 6]]  is: 0 the class is 0 acc.: True
# 117 The prediction for [[95, 73]]  is: 2 the class is 2 acc.: True
# 118 The prediction for [[41, 63]]  is: 5 the class is 5 acc.: True
# 119 The prediction for [[15, 4]]  is: 0 the class is 0 acc.: True
# 120 The prediction for [[44, 8]]  is: 3 the class is 3 acc.: True
# 121 The prediction for [[86, 91]]  is: 2 the class is 2 acc.: True
# 122 The prediction for [[47, 13]]  is: 3 the class is 3 acc.: True
# 123 The prediction for [[40, 37]]  is: 3 the class is 3 acc.: True
# 124 The prediction for [[74, 56]]  is: 1 the class is 1 acc.: True
# 125 The prediction for [[51, 33]]  is: 3 the class is 3 acc.: True
# 126 The prediction for [[27, 39]]  is: 5 the class is 5 acc.: True
# 127 The prediction for [[42, 46]]  is: 5 the class is 5 acc.: True
# 128 The prediction for [[72, 59]]  is: 1 the class is 1 acc.: True
# 129 The prediction for [[82, 97]]  is: 2 the class is 2 acc.: True
# 130 The prediction for [[85, 95]]  is: 2 the class is 2 acc.: True
# 131 The prediction for [[44, 38]]  is: 3 the class is 3 acc.: True
# 132 The prediction for [[45, 13]]  is: 3 the class is 3 acc.: True
# 133 The prediction for [[22, 56]]  is: 5 the class is 5 acc.: True
# 134 The prediction for [[14, 27]]  is: 0 the class is 0 acc.: True
# 135 The prediction for [[51, 51]]  is: 1 the class is 1 acc.: True
# 136 The prediction for [[20, 32]]  is: 0 the class is 0 acc.: True
# 137 The prediction for [[81, 65]]  is: 1 the class is 1 acc.: True
# 138 The prediction for [[27, 75]]  is: 5 the class is 5 acc.: True
# 139 The prediction for [[87, 97]]  is: 2 the class is 2 acc.: True
# 140 The prediction for [[16, 6]]  is: 0 the class is 0 acc.: True
# 141 The prediction for [[37, 40]]  is: 5 the class is 5 acc.: True
# 142 The prediction for [[17, 58]]  is: 5 the class is 5 acc.: True
# 143 The prediction for [[49, 29]]  is: 3 the class is 3 acc.: True
# 144 The prediction for [[3, 6]]  is: 0 the class is 0 acc.: True
# 145 The prediction for [[118, 77]]  is: 2 the class is 2 acc.: True
# 146 The prediction for [[28, 29]]  is: 0 the class is 0 acc.: True
# 147 The prediction for [[16, 86]]  is: 4 the class is 4 acc.: True
# 148 The prediction for [[28, 5]]  is: 0 the class is 0 acc.: True
# 149 The prediction for [[43, 12]]  is: 3 the class is 3 acc.: True
# 150 The prediction for [[78, 73]]  is: 1 the class is 1 acc.: True
# 151 The prediction for [[35, 51]]  is: 5 the class is 5 acc.: True
# 152 The prediction for [[66, 41]]  is: 1 the class is 1 acc.: True
# 153 The prediction for [[72, 93]]  is: 4 the class is 4 acc.: True
# 154 The prediction for [[31, 66]]  is: 5 the class is 5 acc.: True
# 155 The prediction for [[80, 43]]  is: 1 the class is 1 acc.: True
# 156 The prediction for [[43, 14]]  is: 3 the class is 3 acc.: True
# 157 The prediction for [[50, 14]]  is: 3 the class is 3 acc.: True
# 158 The prediction for [[34, 4]]  is: 0 the class is 0 acc.: True
# 159 The prediction for [[99, 91]]  is: 2 the class is 2 acc.: True
# 160 The prediction for [[64, 22]]  is: 3 the class is 3 acc.: True
# 161 The prediction for [[66, 52]]  is: 1 the class is 1 acc.: True
# 162 The prediction for [[24, 51]]  is: 5 the class is 5 acc.: True
# 163 The prediction for [[32, 76]]  is: 4 the class is 4 acc.: True
# 164 The prediction for [[33, 97]]  is: 4 the class is 4 acc.: True
# 165 The prediction for [[31, 71]]  is: 5 the class is 5 acc.: True
# 166 The prediction for [[61, 34]]  is: 3 the class is 3 acc.: True
# 167 The prediction for [[22, 32]]  is: 0 the class is 0 acc.: True
# 168 The prediction for [[45, 63]]  is: 5 the class is 5 acc.: True
# 169 The prediction for [[35, 38]]  is: 5 the class is 5 acc.: True
# 170 The prediction for [[19, 4]]  is: 0 the class is 0 acc.: True
# 171 The prediction for [[52, 95]]  is: 4 the class is 4 acc.: True
# 172 The prediction for [[9, 10]]  is: 0 the class is 0 acc.: True
# 173 The prediction for [[67, 89]]  is: 4 the class is 4 acc.: True
# 174 The prediction for [[52, 32]]  is: 3 the class is 3 acc.: True
# 175 The prediction for [[16, 86]]  is: 4 the class is 4 acc.: True
# 176 The prediction for [[50, 78]]  is: 4 the class is 4 acc.: True
# 177 The prediction for [[40, 32]]  is: 3 the class is 3 acc.: True
# 178 The prediction for [[67, 86]]  is: 4 the class is 4 acc.: True
# 179 The prediction for [[91, 90]]  is: 2 the class is 2 acc.: True
# 180 The prediction for [[68, 62]]  is: 1 the class is 1 acc.: True
# 181 The prediction for [[48, 4]]  is: 3 the class is 3 acc.: True
# 182 The prediction for [[52, 75]]  is: 4 the class is 4 acc.: True
# 183 The prediction for [[13, 21]]  is: 0 the class is 0 acc.: True
# 184 The prediction for [[85, 86]]  is: 2 the class is 2 acc.: True
# 185 The prediction for [[66, 70]]  is: 1 the class is 1 acc.: True
# 186 The prediction for [[14, 41]]  is: 5 the class is 5 acc.: True
# 187 The prediction for [[12, 71]]  is: 5 the class is 5 acc.: True
# 188 The prediction for [[118, 89]]  is: 2 the class is 2 acc.: True
# 189 The prediction for [[60, 53]]  is: 1 the class is 1 acc.: True
# 190 The prediction for [[93, 50]]  is: 1 the class is 1 acc.: True
# 191 The prediction for [[37, 44]]  is: 5 the class is 5 acc.: True
# 192 The prediction for [[51, 45]]  is: 1 the class is 1 acc.: True
# 193 The prediction for [[42, 48]]  is: 5 the class is 5 acc.: True
# 194 The prediction for [[52, 6]]  is: 3 the class is 3 acc.: True
# 195 The prediction for [[38, 81]]  is: 4 the class is 4 acc.: True
# 196 The prediction for [[45, 8]]  is: 3 the class is 3 acc.: True
# 197 The prediction for [[54, 24]]  is: 3 the class is 3 acc.: True
# 198 The prediction for [[54, 26]]  is: 3 the class is 3 acc.: True
# 199 The prediction for [[88, 91]]  is: 2 the class is 2 acc.: True
# 200 The prediction for [[43, 52]]  is: 5 the class is 5 acc.: True
# 201 The prediction for [[9, 6]]  is: 0 the class is 0 acc.: True
# 202 The prediction for [[24, 43]]  is: 5 the class is 5 acc.: True
# 203 The prediction for [[40, 30]]  is: 3 the class is 3 acc.: True
# 204 The prediction for [[60, 13]]  is: 3 the class is 3 acc.: True
# 205 The prediction for [[31, 11]]  is: 0 the class is 0 acc.: True
# 206 The prediction for [[45, 14]]  is: 3 the class is 3 acc.: True
# 207 The prediction for [[59, 34]]  is: 3 the class is 3 acc.: True
# 208 The prediction for [[45, 64]]  is: 5 the class is 5 acc.: True
# 209 The prediction for [[39, 16]]  is: 3 the class is 3 acc.: True
# 210 The prediction for [[21, 44]]  is: 5 the class is 5 acc.: True
# 211 The prediction for [[76, 64]]  is: 1 the class is 1 acc.: True
# 212 The prediction for [[87, 58]]  is: 1 the class is 1 acc.: True
# 213 The prediction for [[85, 91]]  is: 2 the class is 2 acc.: True
# 214 The prediction for [[25, 52]]  is: 5 the class is 5 acc.: True
# 215 The prediction for [[45, 27]]  is: 3 the class is 3 acc.: True
# 216 The prediction for [[47, 7]]  is: 3 the class is 3 acc.: True
# 217 The prediction for [[47, 66]]  is: 5 the class is 5 acc.: True
# 218 The prediction for [[92, 70]]  is: 2 the class is 2 acc.: True
# 219 The prediction for [[51, 32]]  is: 3 the class is 3 acc.: True
# 220 The prediction for [[50, 46]]  is: 5 the class is 5 acc.: True
# 221 The prediction for [[60, 64]]  is: 1 the class is 1 acc.: True
# 222 The prediction for [[79, 65]]  is: 1 the class is 1 acc.: True
# 223 The prediction for [[60, 58]]  is: 1 the class is 1 acc.: True
# 224 The prediction for [[53, 61]]  is: 1 the class is 1 acc.: True
# 225 The prediction for [[116, 69]]  is: 2 the class is 2 acc.: True
# 226 The prediction for [[23, 12]]  is: 0 the class is 0 acc.: True
# 227 The prediction for [[75, 81]]  is: 2 the class is 2 acc.: True
# 228 The prediction for [[95, 84]]  is: 2 the class is 2 acc.: True
# 229 The prediction for [[58, 58]]  is: 1 the class is 1 acc.: True
# 230 The prediction for [[72, 43]]  is: 1 the class is 1 acc.: True
# 231 The prediction for [[49, 55]]  is: 5 the class is 5 acc.: True
# 232 The prediction for [[28, 37]]  is: 5 the class is 5 acc.: True
# 233 The prediction for [[9, 32]]  is: 0 the class is 0 acc.: True
# 234 The prediction for [[64, 38]]  is: 3 the class is 1 acc.: False
# 235 The prediction for [[38, 94]]  is: 4 the class is 4 acc.: True
# 236 The prediction for [[16, 58]]  is: 5 the class is 5 acc.: True
# 237 The prediction for [[70, 31]]  is: 1 the class is 3 acc.: False
# 238 The prediction for [[45, 15]]  is: 3 the class is 3 acc.: True
# 239 The prediction for [[77, 93]]  is: 2 the class is 2 acc.: True
# 240 The prediction for [[22, 8]]  is: 0 the class is 0 acc.: True
# 241 The prediction for [[9, 9]]  is: 0 the class is 0 acc.: True
# 242 The prediction for [[52, 62]]  is: 1 the class is 1 acc.: True
# 243 The prediction for [[72, 29]]  is: 3 the class is 3 acc.: True
# 244 The prediction for [[54, 68]]  is: 4 the class is 4 acc.: True
# 245 The prediction for [[24, 62]]  is: 5 the class is 5 acc.: True
# 246 The prediction for [[41, 35]]  is: 3 the class is 3 acc.: True
# 247 The prediction for [[60, 51]]  is: 1 the class is 1 acc.: True
# 248 The prediction for [[38, 67]]  is: 5 the class is 5 acc.: True
# 249 The prediction for [[73, 86]]  is: 2 the class is 2 acc.: True
# 250 The prediction for [[68, 99]]  is: 4 the class is 4 acc.: True
# 251 The prediction for [[61, 71]]  is: 1 the class is 1 acc.: True
# 252 The prediction for [[96, 93]]  is: 2 the class is 2 acc.: True
# 253 The prediction for [[75, 80]]  is: 2 the class is 2 acc.: True
# 254 The prediction for [[48, 42]]  is: 3 the class is 3 acc.: True
# 255 The prediction for [[32, 5]]  is: 0 the class is 0 acc.: True
# 256 The prediction for [[83, 71]]  is: 2 the class is 2 acc.: True
# 257 The prediction for [[58, 43]]  is: 1 the class is 1 acc.: True
# 258 The prediction for [[25, 25]]  is: 0 the class is 0 acc.: True
# 259 The prediction for [[91, 87]]  is: 2 the class is 2 acc.: True
# 260 The prediction for [[84, 74]]  is: 2 the class is 2 acc.: True
# 261 The prediction for [[107, 82]]  is: 2 the class is 2 acc.: True
# 262 The prediction for [[35, 3]]  is: 0 the class is 0 acc.: True
# 263 The prediction for [[62, 68]]  is: 1 the class is 1 acc.: True
# 264 The prediction for [[10, 71]]  is: 5 the class is 5 acc.: True
# 265 The prediction for [[78, 87]]  is: 2 the class is 2 acc.: True
# 266 The prediction for [[125, 93]]  is: 2 the class is 2 acc.: True
# 267 The prediction for [[27, 21]]  is: 0 the class is 0 acc.: True
# 268 The prediction for [[59, 93]]  is: 4 the class is 4 acc.: True
# 269 The prediction for [[116, 68]]  is: 2 the class is 2 acc.: True
# 270 The prediction for [[28, 16]]  is: 0 the class is 0 acc.: True
# 271 The prediction for [[38, 14]]  is: 3 the class is 3 acc.: True
# 272 The prediction for [[27, 26]]  is: 0 the class is 0 acc.: True
# 273 The prediction for [[8, 76]]  is: 5 the class is 5 acc.: True
# 274 The prediction for [[63, 89]]  is: 4 the class is 4 acc.: True
# 275 The prediction for [[54, 87]]  is: 4 the class is 4 acc.: True
# 276 The prediction for [[51, 32]]  is: 3 the class is 3 acc.: True
# 277 The prediction for [[72, 77]]  is: 1 the class is 1 acc.: True
# 278 The prediction for [[68, 70]]  is: 1 the class is 1 acc.: True
# 279 The prediction for [[102, 77]]  is: 2 the class is 2 acc.: True
# 280 The prediction for [[24, 55]]  is: 5 the class is 5 acc.: True
# 281 The prediction for [[66, 49]]  is: 1 the class is 1 acc.: True
# 282 The prediction for [[63, 25]]  is: 3 the class is 3 acc.: True
# 283 The prediction for [[7, 15]]  is: 0 the class is 0 acc.: True
# 284 The prediction for [[45, 5]]  is: 3 the class is 3 acc.: True
# 285 The prediction for [[49, 25]]  is: 3 the class is 3 acc.: True
# 286 The prediction for [[10, 8]]  is: 0 the class is 0 acc.: True
# 287 The prediction for [[114, 94]]  is: 2 the class is 2 acc.: True
# 288 The prediction for [[66, 90]]  is: 4 the class is 4 acc.: True
# 289 The prediction for [[53, 61]]  is: 1 the class is 1 acc.: True
# 290 The prediction for [[36, 84]]  is: 4 the class is 4 acc.: True
# 291 The prediction for [[70, 48]]  is: 1 the class is 1 acc.: True
# 292 The prediction for [[49, 73]]  is: 4 the class is 4 acc.: True
# 293 The prediction for [[14, 96]]  is: 4 the class is 4 acc.: True
# 294 The prediction for [[66, 93]]  is: 4 the class is 4 acc.: True
# 295 The prediction for [[98, 82]]  is: 2 the class is 2 acc.: True
# 296 The prediction for [[20, 53]]  is: 5 the class is 5 acc.: True
# 297 The prediction for [[58, 60]]  is: 1 the class is 1 acc.: True
# 298 The prediction for [[48, 33]]  is: 3 the class is 3 acc.: True
# 299 The prediction for [[57, 48]]  is: 1 the class is 1 acc.: True
# 300 The prediction for [[107, 91]]  is: 2 the class is 2 acc.: True
# 301 The prediction for [[16, 18]]  is: 0 the class is 0 acc.: True
# 302 The prediction for [[13, 38]]  is: 0 the class is 0 acc.: True
# 303 The prediction for [[119, 89]]  is: 2 the class is 2 acc.: True
# 304 The prediction for [[25, 10]]  is: 0 the class is 0 acc.: True
# 305 The prediction for [[123, 92]]  is: 2 the class is 2 acc.: True
# 306 The prediction for [[90, 85]]  is: 2 the class is 2 acc.: True
# 307 The prediction for [[54, 30]]  is: 3 the class is 3 acc.: True
# 308 The prediction for [[26, 6]]  is: 0 the class is 0 acc.: True
# 309 The prediction for [[39, 68]]  is: 5 the class is 5 acc.: True
# 310 The prediction for [[55, 40]]  is: 1 the class is 3 acc.: False
# 311 The prediction for [[46, 59]]  is: 5 the class is 5 acc.: True
# 312 The prediction for [[97, 66]]  is: 2 the class is 2 acc.: True
# 313 The prediction for [[54, 45]]  is: 1 the class is 1 acc.: True
# 314 The prediction for [[37, 63]]  is: 5 the class is 5 acc.: True
# 315 The prediction for [[33, 25]]  is: 0 the class is 0 acc.: True
# 316 The prediction for [[13, 19]]  is: 0 the class is 0 acc.: True
# 317 The prediction for [[71, 34]]  is: 1 the class is 1 acc.: True
# 318 The prediction for [[52, 49]]  is: 1 the class is 1 acc.: True
# 319 The prediction for [[136, 98]]  is: 2 the class is 2 acc.: True
# 320 The prediction for [[59, 22]]  is: 3 the class is 3 acc.: True
# 321 The prediction for [[71, 39]]  is: 1 the class is 1 acc.: True
# 322 The prediction for [[38, 36]]  is: 3 the class is 3 acc.: True
# 323 The prediction for [[65, 34]]  is: 3 the class is 3 acc.: True
# 324 The prediction for [[51, 13]]  is: 3 the class is 3 acc.: True
# 325 The prediction for [[27, 91]]  is: 4 the class is 4 acc.: True
# 326 The prediction for [[87, 86]]  is: 2 the class is 2 acc.: True
# 327 The prediction for [[50, 5]]  is: 3 the class is 3 acc.: True
# 328 The prediction for [[36, 42]]  is: 5 the class is 5 acc.: True
# 329 The prediction for [[85, 70]]  is: 2 the class is 2 acc.: True
# 330 The prediction for [[38, 45]]  is: 5 the class is 5 acc.: True
# 331 The prediction for [[22, 15]]  is: 0 the class is 0 acc.: True
# 332 The prediction for [[32, 8]]  is: 0 the class is 0 acc.: True
# 333 The prediction for [[6, 55]]  is: 5 the class is 5 acc.: True
# 334 The prediction for [[17, 31]]  is: 0 the class is 0 acc.: True
# 335 The prediction for [[31, 33]]  is: 3 the class is 3 acc.: True
# 336 The prediction for [[68, 78]]  is: 4 the class is 4 acc.: True
# 337 The prediction for [[44, 4]]  is: 3 the class is 3 acc.: True
# 338 The prediction for [[44, 85]]  is: 4 the class is 4 acc.: True
# 339 The prediction for [[20, 2]]  is: 0 the class is 0 acc.: True
# 340 The prediction for [[15, 48]]  is: 5 the class is 5 acc.: True
# 341 The prediction for [[14, 33]]  is: 0 the class is 0 acc.: True
# 342 The prediction for [[99, 59]]  is: 1 the class is 2 acc.: False
# 343 The prediction for [[82, 77]]  is: 2 the class is 2 acc.: True
# 344 The prediction for [[75, 64]]  is: 1 the class is 1 acc.: True
# 345 The prediction for [[39, 14]]  is: 3 the class is 3 acc.: True
# 346 The prediction for [[10, 19]]  is: 0 the class is 0 acc.: True
# 347 The prediction for [[111, 93]]  is: 2 the class is 2 acc.: True
# 348 The prediction for [[13, 1]]  is: 0 the class is 0 acc.: True
# 349 The prediction for [[69, 98]]  is: 4 the class is 4 acc.: True
# 350 The prediction for [[12, 27]]  is: 0 the class is 0 acc.: True
# 351 The prediction for [[42, 78]]  is: 4 the class is 4 acc.: True
# 352 The prediction for [[48, 38]]  is: 3 the class is 3 acc.: True
# 353 The prediction for [[54, 21]]  is: 3 the class is 3 acc.: True
# 354 The prediction for [[102, 84]]  is: 2 the class is 2 acc.: True
# 355 The prediction for [[45, 55]]  is: 5 the class is 5 acc.: True
# 356 The prediction for [[14, 16]]  is: 0 the class is 0 acc.: True
# 357 The prediction for [[50, 63]]  is: 5 the class is 5 acc.: True
# 358 The prediction for [[35, 6]]  is: 0 the class is 0 acc.: True
# 359 The prediction for [[51, 42]]  is: 3 the class is 3 acc.: True
# 360 The prediction for [[38, 39]]  is: 5 the class is 5 acc.: True
# 361 The prediction for [[57, 100]]  is: 4 the class is 4 acc.: True
# 362 The prediction for [[51, 65]]  is: 1 the class is 1 acc.: True
# 363 The prediction for [[89, 99]]  is: 2 the class is 2 acc.: True
# 364 The prediction for [[54, 32]]  is: 3 the class is 3 acc.: True
# 365 The prediction for [[31, 13]]  is: 0 the class is 0 acc.: True
# 366 The prediction for [[62, 31]]  is: 3 the class is 3 acc.: True
# 367 The prediction for [[67, 66]]  is: 1 the class is 1 acc.: True
# 368 The prediction for [[35, 55]]  is: 5 the class is 5 acc.: True
# 369 The prediction for [[65, 60]]  is: 1 the class is 1 acc.: True
# 370 The prediction for [[51, 70]]  is: 4 the class is 4 acc.: True
# 371 The prediction for [[47, 14]]  is: 3 the class is 3 acc.: True
# 372 The prediction for [[96, 88]]  is: 2 the class is 2 acc.: True
# 373 The prediction for [[90, 92]]  is: 2 the class is 2 acc.: True
# 374 The prediction for [[56, 30]]  is: 3 the class is 3 acc.: True
# 375 The prediction for [[59, 34]]  is: 3 the class is 3 acc.: True
# 376 The prediction for [[54, 38]]  is: 3 the class is 3 acc.: True
# 377 The prediction for [[6, 32]]  is: 0 the class is 0 acc.: True
# 378 The prediction for [[18, 31]]  is: 0 the class is 0 acc.: True
# 379 The prediction for [[36, 90]]  is: 4 the class is 4 acc.: True
# 380 The prediction for [[70, 76]]  is: 1 the class is 1 acc.: True
# 381 The prediction for [[109, 66]]  is: 2 the class is 2 acc.: True
# 382 The prediction for [[77, 52]]  is: 1 the class is 1 acc.: True
# 383 The prediction for [[37, 23]]  is: 3 the class is 3 acc.: True
# 384 The prediction for [[88, 97]]  is: 2 the class is 2 acc.: True
# 385 The prediction for [[79, 65]]  is: 1 the class is 1 acc.: True
# 386 The prediction for [[92, 94]]  is: 2 the class is 2 acc.: True
# 387 The prediction for [[64, 83]]  is: 4 the class is 4 acc.: True
# 388 The prediction for [[51, 67]]  is: 4 the class is 4 acc.: True
# 389 The prediction for [[40, 69]]  is: 5 the class is 5 acc.: True
# 390 The prediction for [[63, 74]]  is: 4 the class is 4 acc.: True
# 391 The prediction for [[64, 23]]  is: 3 the class is 3 acc.: True
# 392 The prediction for [[30, 5]]  is: 0 the class is 0 acc.: True
# 393 The prediction for [[49, 55]]  is: 5 the class is 5 acc.: True
# 394 The prediction for [[85, 40]]  is: 1 the class is 1 acc.: True
# 395 The prediction for [[52, 7]]  is: 3 the class is 3 acc.: True
# 396 The prediction for [[46, 37]]  is: 3 the class is 3 acc.: True
# 397 The prediction for [[25, 25]]  is: 0 the class is 0 acc.: True
# 398 The prediction for [[59, 58]]  is: 1 the class is 1 acc.: True
# 399 The prediction for [[38, 37]]  is: 3 the class is 3 acc.: True
# 400 The prediction for [[23, 22]]  is: 0 the class is 0 acc.: True
# 401 The prediction for [[43, 26]]  is: 3 the class is 3 acc.: True
# 402 The prediction for [[43, 98]]  is: 4 the class is 4 acc.: True
# 403 The prediction for [[81, 76]]  is: 2 the class is 2 acc.: True
# 404 The prediction for [[37, 75]]  is: 4 the class is 4 acc.: True
# 405 The prediction for [[25, 13]]  is: 0 the class is 0 acc.: True
# 406 The prediction for [[54, 41]]  is: 3 the class is 3 acc.: True
# 407 The prediction for [[23, 42]]  is: 5 the class is 5 acc.: True
# 408 The prediction for [[37, 56]]  is: 5 the class is 5 acc.: True
# 409 The prediction for [[22, 45]]  is: 5 the class is 5 acc.: True
# 410 The prediction for [[55, 69]]  is: 4 the class is 4 acc.: True
# 411 The prediction for [[87, 100]]  is: 2 the class is 2 acc.: True
# 412 The prediction for [[93, 98]]  is: 2 the class is 2 acc.: True
# 413 The prediction for [[42, 38]]  is: 3 the class is 3 acc.: True
# 414 The prediction for [[40, 26]]  is: 3 the class is 3 acc.: True
# 415 The prediction for [[57, 77]]  is: 4 the class is 4 acc.: True
# 416 The prediction for [[119, 83]]  is: 2 the class is 2 acc.: True
# 417 The prediction for [[95, 97]]  is: 2 the class is 2 acc.: True
# 418 The prediction for [[44, 42]]  is: 5 the class is 5 acc.: True
# 419 The prediction for [[58, 61]]  is: 1 the class is 1 acc.: True
# 420 The prediction for [[37, 3]]  is: 0 the class is 0 acc.: True
# 421 The prediction for [[18, 22]]  is: 0 the class is 0 acc.: True
# 422 The prediction for [[85, 74]]  is: 2 the class is 2 acc.: True
# 423 The prediction for [[47, 52]]  is: 5 the class is 5 acc.: True
# 424 The prediction for [[33, 36]]  is: 5 the class is 5 acc.: True
# 425 The prediction for [[19, 17]]  is: 0 the class is 0 acc.: True
# 426 The prediction for [[61, 74]]  is: 4 the class is 4 acc.: True
# 427 The prediction for [[82, 85]]  is: 2 the class is 2 acc.: True
# 428 The prediction for [[79, 73]]  is: 1 the class is 1 acc.: True
# 429 The prediction for [[46, 7]]  is: 3 the class is 3 acc.: True
# 430 The prediction for [[58, 93]]  is: 4 the class is 4 acc.: True
# 431 The prediction for [[46, 81]]  is: 4 the class is 4 acc.: True
# 432 The prediction for [[34, 34]]  is: 3 the class is 3 acc.: True
# 433 The prediction for [[36, 46]]  is: 5 the class is 5 acc.: True
# 434 The prediction for [[7, 4]]  is: 0 the class is 0 acc.: True
# 435 The prediction for [[38, 70]]  is: 5 the class is 5 acc.: True
# 436 The prediction for [[6, 69]]  is: 5 the class is 5 acc.: True
# 437 The prediction for [[45, 29]]  is: 3 the class is 3 acc.: True
# 438 The prediction for [[61, 96]]  is: 4 the class is 4 acc.: True
# 439 The prediction for [[46, 99]]  is: 4 the class is 4 acc.: True
# 440 The prediction for [[5, 47]]  is: 5 the class is 5 acc.: True
# 441 The prediction for [[50, 52]]  is: 5 the class is 5 acc.: True
# 442 The prediction for [[40, 51]]  is: 5 the class is 5 acc.: True
# 443 The prediction for [[43, 66]]  is: 5 the class is 5 acc.: True
# 444 The prediction for [[5, 95]]  is: 4 the class is 4 acc.: True
# 445 The prediction for [[57, 69]]  is: 1 the class is 1 acc.: True
# 446 The prediction for [[39, 71]]  is: 5 the class is 5 acc.: True
# 447 The prediction for [[94, 86]]  is: 2 the class is 2 acc.: True
# 448 The prediction for [[16, 84]]  is: 4 the class is 4 acc.: True
# 449 The prediction for [[56, 90]]  is: 4 the class is 4 acc.: True
# 450 The prediction for [[76, 68]]  is: 1 the class is 1 acc.: True
# 451 The prediction for [[38, 3]]  is: 0 the class is 0 acc.: True
# 452 The prediction for [[39, 31]]  is: 3 the class is 3 acc.: True
# 453 The prediction for [[38, 11]]  is: 3 the class is 3 acc.: True
# 454 The prediction for [[28, 58]]  is: 5 the class is 5 acc.: True
# 455 The prediction for [[115, 85]]  is: 2 the class is 2 acc.: True
# 456 The prediction for [[42, 57]]  is: 5 the class is 5 acc.: True
# 457 The prediction for [[39, 11]]  is: 3 the class is 3 acc.: True
# 458 The prediction for [[40, 23]]  is: 3 the class is 3 acc.: True
# 459 The prediction for [[72, 33]]  is: 1 the class is 1 acc.: True
# 460 The prediction for [[64, 33]]  is: 3 the class is 3 acc.: True
# 461 The prediction for [[45, 67]]  is: 5 the class is 5 acc.: True
# 462 The prediction for [[43, 1]]  is: 3 the class is 3 acc.: True
# 463 The prediction for [[11, 81]]  is: 5 the class is 5 acc.: True
# 464 The prediction for [[102, 85]]  is: 2 the class is 2 acc.: True
# 465 The prediction for [[45, 71]]  is: 4 the class is 4 acc.: True
# 466 The prediction for [[121, 84]]  is: 2 the class is 2 acc.: True
# 467 The prediction for [[50, 62]]  is: 5 the class is 5 acc.: True
# 468 The prediction for [[31, 31]]  is: 3 the class is 3 acc.: True
# 469 The prediction for [[57, 52]]  is: 1 the class is 1 acc.: True
# 470 The prediction for [[8, 65]]  is: 5 the class is 5 acc.: True
# 471 The prediction for [[51, 93]]  is: 4 the class is 4 acc.: True
# 472 The prediction for [[29, 29]]  is: 0 the class is 0 acc.: True
# 473 The prediction for [[16, 15]]  is: 0 the class is 0 acc.: True
# 474 The prediction for [[42, 16]]  is: 3 the class is 3 acc.: True
# 475 The prediction for [[43, 93]]  is: 4 the class is 4 acc.: True
# 476 The prediction for [[10, 7]]  is: 0 the class is 0 acc.: True
# 477 The prediction for [[25, 57]]  is: 5 the class is 5 acc.: True
# 478 The prediction for [[10, 6]]  is: 0 the class is 0 acc.: True
# 479 The prediction for [[61, 81]]  is: 4 the class is 4 acc.: True
# 480 The prediction for [[44, 4]]  is: 3 the class is 3 acc.: True
# 481 The prediction for [[34, 39]]  is: 5 the class is 5 acc.: True
# 482 The prediction for [[31, 58]]  is: 5 the class is 5 acc.: True
# 483 The prediction for [[60, 95]]  is: 4 the class is 4 acc.: True
# 484 The prediction for [[32, 5]]  is: 0 the class is 0 acc.: True
# 485 The prediction for [[46, 46]]  is: 5 the class is 5 acc.: True
# 486 The prediction for [[89, 51]]  is: 1 the class is 1 acc.: True
# 487 The prediction for [[73, 92]]  is: 2 the class is 2 acc.: True
# 488 The prediction for [[55, 56]]  is: 1 the class is 1 acc.: True
# 489 The prediction for [[22, 77]]  is: 5 the class is 5 acc.: True
# 490 The prediction for [[11, 37]]  is: 0 the class is 0 acc.: True
# 491 The prediction for [[125, 90]]  is: 2 the class is 2 acc.: True
# 492 The prediction for [[45, 51]]  is: 5 the class is 5 acc.: True
# 493 The prediction for [[42, 20]]  is: 3 the class is 3 acc.: True
# 494 The prediction for [[39, 62]]  is: 5 the class is 5 acc.: True
# 495 The prediction for [[36, 58]]  is: 5 the class is 5 acc.: True
# 496 The prediction for [[38, 95]]  is: 4 the class is 4 acc.: True
# 497 The prediction for [[39, 44]]  is: 5 the class is 5 acc.: True
# 498 The prediction for [[56, 11]]  is: 3 the class is 3 acc.: True
# 499 The prediction for [[54, 41]]  is: 3 the class is 3 acc.: True
# 500 The prediction for [[81, 80]]  is: 2 the class is 2 acc.: True
# 501 The prediction for [[40, 39]]  is: 3 the class is 3 acc.: True
# 502 The prediction for [[120, 99]]  is: 2 the class is 2 acc.: True
# 503 The prediction for [[41, 66]]  is: 5 the class is 5 acc.: True
# 504 The prediction for [[100, 98]]  is: 2 the class is 2 acc.: True
# 505 The prediction for [[22, 69]]  is: 5 the class is 5 acc.: True
# 506 The prediction for [[44, 25]]  is: 3 the class is 3 acc.: True
# 507 The prediction for [[102, 98]]  is: 2 the class is 2 acc.: True
# 508 The prediction for [[93, 88]]  is: 2 the class is 2 acc.: True
# 509 The prediction for [[56, 9]]  is: 3 the class is 3 acc.: True
# 510 The prediction for [[55, 83]]  is: 4 the class is 4 acc.: True
# 511 The prediction for [[90, 73]]  is: 2 the class is 2 acc.: True
# 512 The prediction for [[48, 91]]  is: 4 the class is 4 acc.: True
# 513 The prediction for [[34, 99]]  is: 4 the class is 4 acc.: True
# 514 The prediction for [[80, 66]]  is: 1 the class is 1 acc.: True
# 515 The prediction for [[17, 62]]  is: 5 the class is 5 acc.: True
# 516 The prediction for [[58, 65]]  is: 1 the class is 1 acc.: True
# 517 The prediction for [[51, 28]]  is: 3 the class is 3 acc.: True
# 518 The prediction for [[72, 34]]  is: 1 the class is 1 acc.: True
# 519 The prediction for [[17, 10]]  is: 0 the class is 0 acc.: True
# 520 The prediction for [[32, 58]]  is: 5 the class is 5 acc.: True
# 521 The prediction for [[54, 30]]  is: 3 the class is 3 acc.: True
# 522 The prediction for [[50, 43]]  is: 3 the class is 3 acc.: True
# 523 The prediction for [[55, 29]]  is: 3 the class is 3 acc.: True
# 524 The prediction for [[89, 85]]  is: 2 the class is 2 acc.: True
# 525 The prediction for [[42, 64]]  is: 5 the class is 5 acc.: True
# 526 The prediction for [[89, 95]]  is: 2 the class is 2 acc.: True
# 527 The prediction for [[58, 86]]  is: 4 the class is 4 acc.: True
# 528 The prediction for [[53, 44]]  is: 1 the class is 1 acc.: True
# 529 The prediction for [[86, 87]]  is: 2 the class is 2 acc.: True
# 530 The prediction for [[25, 30]]  is: 0 the class is 0 acc.: True
# 531 The prediction for [[74, 43]]  is: 1 the class is 1 acc.: True
# 532 The prediction for [[34, 3]]  is: 0 the class is 0 acc.: True
# 533 The prediction for [[9, 12]]  is: 0 the class is 0 acc.: True
# 534 The prediction for [[8, 31]]  is: 0 the class is 0 acc.: True
# 535 The prediction for [[67, 96]]  is: 4 the class is 4 acc.: True
# 536 The prediction for [[19, 12]]  is: 0 the class is 0 acc.: True
# 537 The prediction for [[53, 75]]  is: 4 the class is 4 acc.: True
# 538 The prediction for [[78, 68]]  is: 1 the class is 1 acc.: True
# 539 The prediction for [[14, 64]]  is: 5 the class is 5 acc.: True
# 540 The prediction for [[45, 46]]  is: 5 the class is 5 acc.: True
# 541 The prediction for [[125, 82]]  is: 2 the class is 2 acc.: True
# 542 The prediction for [[57, 50]]  is: 1 the class is 1 acc.: True
# 543 The prediction for [[17, 9]]  is: 0 the class is 0 acc.: True
# 544 The prediction for [[34, 81]]  is: 4 the class is 4 acc.: True
# 545 The prediction for [[111, 75]]  is: 2 the class is 2 acc.: True
# 546 The prediction for [[74, 64]]  is: 1 the class is 1 acc.: True
# 547 The prediction for [[48, 53]]  is: 5 the class is 5 acc.: True
# 548 The prediction for [[69, 67]]  is: 1 the class is 1 acc.: True
# 549 The prediction for [[19, 2]]  is: 0 the class is 0 acc.: True
# 550 The prediction for [[59, 66]]  is: 1 the class is 1 acc.: True
# 551 The prediction for [[43, 66]]  is: 5 the class is 5 acc.: True
# 552 The prediction for [[101, 71]]  is: 2 the class is 2 acc.: True
# 553 The prediction for [[69, 62]]  is: 1 the class is 1 acc.: True
# 554 The prediction for [[58, 61]]  is: 1 the class is 1 acc.: True
# 555 The prediction for [[45, 18]]  is: 3 the class is 3 acc.: True
# 556 The prediction for [[44, 44]]  is: 5 the class is 5 acc.: True
# 557 The prediction for [[16, 24]]  is: 0 the class is 0 acc.: True
# 558 The prediction for [[87, 63]]  is: 1 the class is 1 acc.: True
# 559 The prediction for [[73, 59]]  is: 1 the class is 1 acc.: True
# 560 The prediction for [[99, 63]]  is: 2 the class is 2 acc.: True
# 561 The prediction for [[26, 74]]  is: 5 the class is 5 acc.: True
# 562 The prediction for [[14, 68]]  is: 5 the class is 5 acc.: True
# 563 The prediction for [[50, 30]]  is: 3 the class is 3 acc.: True
# 564 The prediction for [[49, 8]]  is: 3 the class is 3 acc.: True
# 565 The prediction for [[25, 32]]  is: 0 the class is 0 acc.: True
# 566 The prediction for [[46, 48]]  is: 5 the class is 5 acc.: True
# 567 The prediction for [[31, 38]]  is: 5 the class is 5 acc.: True
# 568 The prediction for [[44, 11]]  is: 3 the class is 3 acc.: True
# 569 The prediction for [[35, 31]]  is: 3 the class is 3 acc.: True
# 570 The prediction for [[32, 55]]  is: 5 the class is 5 acc.: True
# 571 The prediction for [[38, 29]]  is: 3 the class is 3 acc.: True
# 572 The prediction for [[81, 72]]  is: 2 the class is 2 acc.: True
# 573 The prediction for [[9, 16]]  is: 0 the class is 0 acc.: True
# 574 The prediction for [[42, 66]]  is: 5 the class is 5 acc.: True
# 575 The prediction for [[74, 64]]  is: 1 the class is 1 acc.: True
# 576 The prediction for [[50, 70]]  is: 4 the class is 4 acc.: True
# 577 The prediction for [[67, 36]]  is: 1 the class is 1 acc.: True
# 578 The prediction for [[70, 99]]  is: 4 the class is 4 acc.: True
# 579 The prediction for [[24, 1]]  is: 0 the class is 0 acc.: True
# 580 The prediction for [[78, 53]]  is: 1 the class is 1 acc.: True
# 581 The prediction for [[82, 79]]  is: 2 the class is 2 acc.: True
# 582 The prediction for [[31, 4]]  is: 0 the class is 0 acc.: True
# 583 The prediction for [[42, 51]]  is: 5 the class is 5 acc.: True
# 584 The prediction for [[57, 100]]  is: 4 the class is 4 acc.: True
# 585 The prediction for [[25, 19]]  is: 0 the class is 0 acc.: True
# 586 The prediction for [[55, 38]]  is: 3 the class is 3 acc.: True
# 587 The prediction for [[98, 100]]  is: 2 the class is 2 acc.: True
# 588 The prediction for [[51, 16]]  is: 3 the class is 3 acc.: True
# 589 The prediction for [[29, 78]]  is: 4 the class is 4 acc.: True
# 590 The prediction for [[69, 100]]  is: 4 the class is 4 acc.: True
# 591 The prediction for [[9, 85]]  is: 5 the class is 5 acc.: True
# 592 The prediction for [[31, 23]]  is: 0 the class is 0 acc.: True
# 593 The prediction for [[18, 62]]  is: 5 the class is 5 acc.: True
# 594 The prediction for [[63, 39]]  is: 1 the class is 1 acc.: True
# 595 The prediction for [[25, 46]]  is: 5 the class is 5 acc.: True
# 596 The prediction for [[41, 19]]  is: 3 the class is 3 acc.: True
# 597 The prediction for [[33, 66]]  is: 5 the class is 5 acc.: True
# 598 The prediction for [[42, 18]]  is: 3 the class is 3 acc.: True
# 599 The prediction for [[49, 61]]  is: 5 the class is 5 acc.: True
# 600 The prediction for [[22, 11]]  is: 0 the class is 0 acc.: True
# 601 The prediction for [[49, 59]]  is: 5 the class is 5 acc.: True
# 602 The prediction for [[32, 86]]  is: 4 the class is 4 acc.: True
# 603 The prediction for [[42, 54]]  is: 5 the class is 5 acc.: True
# 604 The prediction for [[21, 78]]  is: 5 the class is 5 acc.: True
# 605 The prediction for [[76, 94]]  is: 2 the class is 2 acc.: True
# 606 The prediction for [[33, 5]]  is: 0 the class is 0 acc.: True
# 607 The prediction for [[49, 57]]  is: 5 the class is 5 acc.: True
# 608 The prediction for [[87, 63]]  is: 1 the class is 1 acc.: True
# 609 The prediction for [[69, 82]]  is: 4 the class is 4 acc.: True
# 610 The prediction for [[93, 56]]  is: 1 the class is 1 acc.: True
# 611 The prediction for [[43, 17]]  is: 3 the class is 3 acc.: True
# 612 The prediction for [[29, 2]]  is: 0 the class is 0 acc.: True
# 613 The prediction for [[72, 32]]  is: 1 the class is 1 acc.: True
# 614 The prediction for [[63, 19]]  is: 3 the class is 3 acc.: True
# 615 The prediction for [[5, 2]]  is: 0 the class is 0 acc.: True
# 616 The prediction for [[24, 46]]  is: 5 the class is 5 acc.: True
# 617 The prediction for [[39, 76]]  is: 4 the class is 4 acc.: True
# 618 The prediction for [[61, 49]]  is: 1 the class is 1 acc.: True
# 619 The prediction for [[79, 63]]  is: 1 the class is 1 acc.: True
# 620 The prediction for [[26, 21]]  is: 0 the class is 0 acc.: True
# 621 The prediction for [[21, 17]]  is: 0 the class is 0 acc.: True
# 622 The prediction for [[35, 48]]  is: 5 the class is 5 acc.: True
# 623 The prediction for [[48, 36]]  is: 3 the class is 3 acc.: True
# 624 The prediction for [[8, 41]]  is: 5 the class is 5 acc.: True
# 625 The prediction for [[60, 58]]  is: 1 the class is 1 acc.: True
# 626 The prediction for [[61, 74]]  is: 4 the class is 4 acc.: True
# 627 The prediction for [[87, 98]]  is: 2 the class is 2 acc.: True
# 628 The prediction for [[58, 59]]  is: 1 the class is 1 acc.: True
# 629 The prediction for [[75, 93]]  is: 2 the class is 2 acc.: True
# 630 The prediction for [[51, 91]]  is: 4 the class is 4 acc.: True
# 631 The prediction for [[32, 44]]  is: 5 the class is 5 acc.: True
# 632 The prediction for [[79, 52]]  is: 1 the class is 1 acc.: True
# 633 The prediction for [[30, 30]]  is: 0 the class is 0 acc.: True
# 634 The prediction for [[130, 98]]  is: 2 the class is 2 acc.: True
# 635 The prediction for [[26, 24]]  is: 0 the class is 0 acc.: True
# 636 The prediction for [[24, 10]]  is: 0 the class is 0 acc.: True
# 637 The prediction for [[41, 84]]  is: 4 the class is 4 acc.: True
# 638 The prediction for [[52, 44]]  is: 3 the class is 3 acc.: True
# 639 The prediction for [[76, 81]]  is: 2 the class is 2 acc.: True
# 640 The prediction for [[41, 87]]  is: 4 the class is 4 acc.: True
# 641 The prediction for [[70, 46]]  is: 1 the class is 1 acc.: True
# 642 The prediction for [[58, 14]]  is: 3 the class is 3 acc.: True
# 643 The prediction for [[78, 55]]  is: 1 the class is 1 acc.: True
# 644 The prediction for [[41, 11]]  is: 3 the class is 3 acc.: True
# 645 The prediction for [[48, 13]]  is: 3 the class is 3 acc.: True
# 646 The prediction for [[55, 20]]  is: 3 the class is 3 acc.: True
# 647 The prediction for [[72, 47]]  is: 1 the class is 1 acc.: True
# 648 The prediction for [[104, 95]]  is: 2 the class is 2 acc.: True
# 649 The prediction for [[34, 97]]  is: 4 the class is 4 acc.: True
# 650 The prediction for [[53, 96]]  is: 4 the class is 4 acc.: True
# 651 The prediction for [[25, 35]]  is: 0 the class is 0 acc.: True
# 652 The prediction for [[69, 87]]  is: 4 the class is 4 acc.: True
# 653 The prediction for [[67, 23]]  is: 3 the class is 3 acc.: True
# 654 The prediction for [[23, 5]]  is: 0 the class is 0 acc.: True
# 655 The prediction for [[43, 62]]  is: 5 the class is 5 acc.: True
# 656 The prediction for [[32, 17]]  is: 0 the class is 0 acc.: True
# 657 The prediction for [[47, 62]]  is: 5 the class is 5 acc.: True
# 658 The prediction for [[15, 90]]  is: 4 the class is 4 acc.: True
# 659 The prediction for [[125, 89]]  is: 2 the class is 2 acc.: True
# 660 The prediction for [[31, 19]]  is: 0 the class is 0 acc.: True
# 661 The prediction for [[21, 7]]  is: 0 the class is 0 acc.: True
# 662 The prediction for [[23, 25]]  is: 0 the class is 0 acc.: True
# 663 The prediction for [[79, 80]]  is: 2 the class is 2 acc.: True
# 664 The prediction for [[13, 1]]  is: 0 the class is 0 acc.: True
# 665 The prediction for [[80, 56]]  is: 1 the class is 1 acc.: True
# 666 The prediction for [[63, 62]]  is: 1 the class is 1 acc.: True
# 667 The prediction for [[83, 87]]  is: 2 the class is 2 acc.: True
# 668 The prediction for [[62, 79]]  is: 4 the class is 4 acc.: True
# 669 The prediction for [[59, 60]]  is: 1 the class is 1 acc.: True
# 670 The prediction for [[38, 17]]  is: 3 the class is 3 acc.: True
# 671 The prediction for [[24, 53]]  is: 5 the class is 5 acc.: True
# 672 The prediction for [[29, 74]]  is: 5 the class is 5 acc.: True
# 673 The prediction for [[22, 16]]  is: 0 the class is 0 acc.: True
# 674 The prediction for [[17, 72]]  is: 5 the class is 5 acc.: True
# 675 The prediction for [[46, 56]]  is: 5 the class is 5 acc.: True
# 676 The prediction for [[53, 86]]  is: 4 the class is 4 acc.: True
# 677 The prediction for [[89, 84]]  is: 2 the class is 2 acc.: True
# 678 The prediction for [[42, 40]]  is: 5 the class is 3 acc.: False
# 679 The prediction for [[43, 59]]  is: 5 the class is 5 acc.: True
# 680 The prediction for [[58, 85]]  is: 4 the class is 4 acc.: True
# 681 The prediction for [[32, 82]]  is: 4 the class is 4 acc.: True
# 682 The prediction for [[13, 11]]  is: 0 the class is 0 acc.: True
# 683 The prediction for [[22, 93]]  is: 4 the class is 4 acc.: True
# 684 The prediction for [[92, 74]]  is: 2 the class is 2 acc.: True
# 685 The prediction for [[28, 25]]  is: 0 the class is 0 acc.: True
# 686 The prediction for [[44, 87]]  is: 4 the class is 4 acc.: True
# 687 The prediction for [[73, 79]]  is: 2 the class is 2 acc.: True
# 688 The prediction for [[16, 91]]  is: 4 the class is 4 acc.: True
# 689 The prediction for [[51, 65]]  is: 1 the class is 1 acc.: True
# 690 The prediction for [[46, 33]]  is: 3 the class is 3 acc.: True
# 691 The prediction for [[17, 11]]  is: 0 the class is 0 acc.: True
# 692 The prediction for [[51, 43]]  is: 3 the class is 3 acc.: True
# 693 The prediction for [[85, 94]]  is: 2 the class is 2 acc.: True
# 694 The prediction for [[49, 71]]  is: 4 the class is 4 acc.: True
# 695 The prediction for [[97, 83]]  is: 2 the class is 2 acc.: True
# 696 The prediction for [[34, 35]]  is: 3 the class is 3 acc.: True
# 697 The prediction for [[64, 89]]  is: 4 the class is 4 acc.: True
# 698 The prediction for [[45, 63]]  is: 5 the class is 5 acc.: True
# 699 The prediction for [[44, 14]]  is: 3 the class is 3 acc.: True
# 700 The prediction for [[54, 9]]  is: 3 the class is 3 acc.: True
# 701 The prediction for [[7, 64]]  is: 5 the class is 5 acc.: True
# 702 The prediction for [[40, 58]]  is: 5 the class is 5 acc.: True
# 703 The prediction for [[50, 35]]  is: 3 the class is 3 acc.: True
# 704 The prediction for [[37, 14]]  is: 3 the class is 3 acc.: True
# 705 The prediction for [[41, 62]]  is: 5 the class is 5 acc.: True
# 706 The prediction for [[28, 97]]  is: 4 the class is 4 acc.: True
# 707 The prediction for [[69, 65]]  is: 1 the class is 1 acc.: True
# 708 The prediction for [[27, 8]]  is: 0 the class is 0 acc.: True
# 709 The prediction for [[73, 64]]  is: 1 the class is 1 acc.: True
# 710 The prediction for [[43, 3]]  is: 3 the class is 3 acc.: True
# 711 The prediction for [[16, 26]]  is: 0 the class is 0 acc.: True
# 712 The prediction for [[13, 1]]  is: 0 the class is 0 acc.: True
# 713 The prediction for [[35, 68]]  is: 5 the class is 5 acc.: True
# 714 The prediction for [[42, 68]]  is: 5 the class is 5 acc.: True
# 715 The prediction for [[37, 14]]  is: 3 the class is 3 acc.: True
# 716 The prediction for [[54, 41]]  is: 3 the class is 3 acc.: True
# 717 The prediction for [[37, 40]]  is: 5 the class is 5 acc.: True
# 718 The prediction for [[23, 28]]  is: 0 the class is 0 acc.: True
# ...
# 763 The prediction for [[33, 15]]  is: 0 the class is 0 acc.: True
# 764 The prediction for [[56, 24]]  is: 3 the class is 3 acc.: True
# 765 The prediction for [[53, 55]]  is: 1 the class is 1 acc.: True
# 766 The prediction for [[68, 71]]  is: 1 the class is 1 acc.: True
# 767 The prediction for [[87, 40]]  is: 1 the class is 1 acc.: True
# 768 The prediction for [[35, 22]]  is: 3 the class is 3 acc.: True
# 769 The prediction for [[73, 66]]  is: 1 the class is 1 acc.: True
# 770 The prediction for [[38, 53]]  is: 5 the class is 5 acc.: True
# 771 The prediction for [[8, 74]]  is: 5 the class is 5 acc.: True
# 772 The prediction for [[31, 56]]  is: 5 the class is 5 acc.: True
# 773 The prediction for [[73, 71]]  is: 1 the class is 1 acc.: True
# 774 The prediction for [[50, 68]]  is: 4 the class is 4 acc.: True
# 775 The prediction for [[119, 79]]  is: 2 the class is 2 acc.: True
# 776 The prediction for [[79, 89]]  is: 2 the class is 2 acc.: True
# 777 The prediction for [[70, 41]]  is: 1 the class is 1 acc.: True
# 778 The prediction for [[48, 18]]  is: 3 the class is 3 acc.: True
# 779 The prediction for [[12, 7]]  is: 0 the class is 0 acc.: True
# 780 The prediction for [[35, 30]]  is: 3 the class is 3 acc.: True
# 781 The prediction for [[44, 43]]  is: 5 the class is 5 acc.: True
# 782 The prediction for [[8, 1]]  is: 0 the class is 0 acc.: True
# 783 The prediction for [[47, 94]]  is: 4 the class is 4 acc.: True
# 784 The prediction for [[80, 71]]  is: 1 the class is 1 acc.: True
# 785 The prediction for [[26, 65]]  is: 5 the class is 5 acc.: True
# 786 The prediction for [[55, 29]]  is: 3 the class is 3 acc.: True
# 787 The prediction for [[53, 37]]  is: 3 the class is 3 acc.: True
# 788 The prediction for [[33, 47]]  is: 5 the class is 5 acc.: True
# 789 The prediction for [[60, 93]]  is: 4 the class is 4 acc.: True
# 790 The prediction for [[100, 62]]  is: 2 the class is 2 acc.: True
# 791 The prediction for [[57, 53]]  is: 1 the class is 1 acc.: True
# 792 The prediction for [[75, 93]]  is: 2 the class is 2 acc.: True
# 793 The prediction for [[11, 99]]  is: 4 the class is 4 acc.: True
# 794 The prediction for [[41, 50]]  is: 5 the class is 5 acc.: True
# 795 The prediction for [[46, 38]]  is: 3 the class is 3 acc.: True
# 796 The prediction for [[59, 57]]  is: 1 the class is 1 acc.: True
# 797 The prediction for [[106, 80]]  is: 2 the class is 2 acc.: True
# 798 The prediction for [[19, 3]]  is: 0 the class is 0 acc.: True
# 799 The prediction for [[54, 44]]  is: 1 the class is 1 acc.: True
# 800 The prediction for [[54, 80]]  is: 4 the class is 4 acc.: True
# 801 The prediction for [[70, 93]]  is: 4 the class is 4 acc.: True
# 802 The prediction for [[44, 97]]  is: 4 the class is 4 acc.: True
# 803 The prediction for [[50, 81]]  is: 4 the class is 4 acc.: True
# 804 The prediction for [[50, 27]]  is: 3 the class is 3 acc.: True
# 805 The prediction for [[57, 50]]  is: 1 the class is 1 acc.: True
# 806 The prediction for [[55, 82]]  is: 4 the class is 4 acc.: True
# 807 The prediction for [[61, 42]]  is: 1 the class is 1 acc.: True
# 808 The prediction for [[80, 60]]  is: 1 the class is 1 acc.: True
# 809 The prediction for [[74, 73]]  is: 1 the class is 1 acc.: True
# 810 The prediction for [[74, 70]]  is: 1 the class is 1 acc.: True
# 811 The prediction for [[46, 35]]  is: 3 the class is 3 acc.: True
# 812 The prediction for [[42, 21]]  is: 3 the class is 3 acc.: True
# 813 The prediction for [[87, 96]]  is: 2 the class is 2 acc.: True
# 814 The prediction for [[36, 38]]  is: 5 the class is 5 acc.: True
# 815 The prediction for [[32, 35]]  is: 3 the class is 3 acc.: True
# 816 The prediction for [[15, 5]]  is: 0 the class is 0 acc.: True
# 817 The prediction for [[80, 75]]  is: 2 the class is 2 acc.: True
# 818 The prediction for [[57, 67]]  is: 1 the class is 1 acc.: True
# 819 The prediction for [[34, 15]]  is: 0 the class is 0 acc.: True
# 820 The prediction for [[59, 61]]  is: 1 the class is 1 acc.: True
# 821 The prediction for [[56, 26]]  is: 3 the class is 3 acc.: True
# 822 The prediction for [[34, 24]]  is: 3 the class is 3 acc.: True
# 823 The prediction for [[20, 54]]  is: 5 the class is 5 acc.: True
# 824 The prediction for [[46, 25]]  is: 3 the class is 3 acc.: True
# 825 The prediction for [[116, 77]]  is: 2 the class is 2 acc.: True
# 826 The prediction for [[60, 42]]  is: 1 the class is 1 acc.: True
# 827 The prediction for [[44, 87]]  is: 4 the class is 4 acc.: True
# 828 The prediction for [[23, 51]]  is: 5 the class is 5 acc.: True
# 829 The prediction for [[85, 85]]  is: 2 the class is 2 acc.: True
# 830 The prediction for [[17, 16]]  is: 0 the class is 0 acc.: True
# 831 The prediction for [[75, 63]]  is: 1 the class is 1 acc.: True
# 832 The prediction for [[54, 42]]  is: 3 the class is 3 acc.: True
# 833 The prediction for [[101, 79]]  is: 2 the class is 2 acc.: True
# 834 The prediction for [[16, 29]]  is: 0 the class is 0 acc.: True
# 835 The prediction for [[82, 92]]  is: 2 the class is 2 acc.: True
# 836 The prediction for [[71, 84]]  is: 4 the class is 4 acc.: True
# 837 The prediction for [[55, 59]]  is: 1 the class is 1 acc.: True
# 838 The prediction for [[76, 78]]  is: 2 the class is 2 acc.: True
# 839 The prediction for [[67, 87]]  is: 4 the class is 4 acc.: True
# 840 The prediction for [[110, 75]]  is: 2 the class is 2 acc.: True
# 841 The prediction for [[33, 96]]  is: 4 the class is 4 acc.: True
# 842 The prediction for [[64, 22]]  is: 3 the class is 3 acc.: True
# 843 The prediction for [[46, 66]]  is: 5 the class is 5 acc.: True
# 844 The prediction for [[10, 2]]  is: 0 the class is 0 acc.: True
# 845 The prediction for [[8, 5]]  is: 0 the class is 0 acc.: True
# 846 The prediction for [[47, 49]]  is: 5 the class is 5 acc.: True
# 847 The prediction for [[49, 26]]  is: 3 the class is 3 acc.: True
# 848 The prediction for [[104, 81]]  is: 2 the class is 2 acc.: True
# 849 The prediction for [[103, 78]]  is: 2 the class is 2 acc.: True
# 850 The prediction for [[32, 11]]  is: 0 the class is 0 acc.: True
# 851 The prediction for [[87, 83]]  is: 2 the class is 2 acc.: True
# 852 The prediction for [[30, 21]]  is: 0 the class is 0 acc.: True
# 853 The prediction for [[13, 8]]  is: 0 the class is 0 acc.: True
# 854 The prediction for [[70, 47]]  is: 1 the class is 1 acc.: True
# 855 The prediction for [[35, 43]]  is: 5 the class is 5 acc.: True
# 856 The prediction for [[54, 93]]  is: 4 the class is 4 acc.: True
# 857 The prediction for [[49, 58]]  is: 5 the class is 5 acc.: True
# 858 The prediction for [[112, 66]]  is: 2 the class is 2 acc.: True
# 859 The prediction for [[20, 21]]  is: 0 the class is 0 acc.: True
# 860 The prediction for [[55, 67]]  is: 1 the class is 1 acc.: True
# 861 The prediction for [[50, 17]]  is: 3 the class is 3 acc.: True
# 862 The prediction for [[11, 5]]  is: 0 the class is 0 acc.: True
# 863 The prediction for [[20, 9]]  is: 0 the class is 0 acc.: True
# 864 The prediction for [[50, 19]]  is: 3 the class is 3 acc.: True
# 865 The prediction for [[62, 39]]  is: 1 the class is 1 acc.: True
# 866 The prediction for [[39, 4]]  is: 0 the class is 0 acc.: True
# 867 The prediction for [[66, 45]]  is: 1 the class is 1 acc.: True
# 868 The prediction for [[27, 35]]  is: 5 the class is 5 acc.: True
# 869 The prediction for [[57, 79]]  is: 4 the class is 4 acc.: True
# 870 The prediction for [[18, 44]]  is: 5 the class is 5 acc.: True
# 871 The prediction for [[59, 20]]  is: 3 the class is 3 acc.: True
# 872 The prediction for [[34, 42]]  is: 5 the class is 5 acc.: True
# 873 The prediction for [[48, 48]]  is: 5 the class is 5 acc.: True
# 874 The prediction for [[78, 45]]  is: 1 the class is 1 acc.: True
# 875 The prediction for [[31, 94]]  is: 4 the class is 4 acc.: True
# 876 The prediction for [[20, 20]]  is: 0 the class is 0 acc.: True
# 877 The prediction for [[23, 14]]  is: 0 the class is 0 acc.: True
# 878 The prediction for [[53, 33]]  is: 3 the class is 3 acc.: True
# 879 The prediction for [[16, 24]]  is: 0 the class is 0 acc.: True
# 880 The prediction for [[73, 49]]  is: 1 the class is 1 acc.: True
# 881 The prediction for [[44, 51]]  is: 5 the class is 5 acc.: True
# 882 The prediction for [[36, 15]]  is: 0 the class is 0 acc.: True
# 883 The prediction for [[18, 46]]  is: 5 the class is 5 acc.: True
# 884 The prediction for [[30, 22]]  is: 0 the class is 0 acc.: True
# 885 The prediction for [[83, 87]]  is: 2 the class is 2 acc.: True
# 886 The prediction for [[18, 42]]  is: 5 the class is 5 acc.: True
# 887 The prediction for [[41, 24]]  is: 3 the class is 3 acc.: True
# 888 The prediction for [[16, 84]]  is: 4 the class is 4 acc.: True
# 889 The prediction for [[67, 59]]  is: 1 the class is 1 acc.: True
# 890 The prediction for [[9, 18]]  is: 0 the class is 0 acc.: True
# 891 The prediction for [[49, 74]]  is: 4 the class is 4 acc.: True
# 892 The prediction for [[41, 48]]  is: 5 the class is 5 acc.: True
# 893 The prediction for [[65, 50]]  is: 1 the class is 1 acc.: True
# 894 The prediction for [[29, 8]]  is: 0 the class is 0 acc.: True
# 895 The prediction for [[30, 16]]  is: 0 the class is 0 acc.: True
# 896 The prediction for [[45, 67]]  is: 5 the class is 5 acc.: True
# 897 The prediction for [[7, 50]]  is: 5 the class is 5 acc.: True
# 898 The prediction for [[68, 32]]  is: 3 the class is 3 acc.: True
# 899 The prediction for [[83, 62]]  is: 1 the class is 1 acc.: True
# 900 The prediction for [[21, 38]]  is: 0 the class is 5 acc.: False
# 901 The prediction for [[36, 27]]  is: 3 the class is 3 acc.: True
# 902 The prediction for [[53, 44]]  is: 1 the class is 1 acc.: True
# 903 The prediction for [[65, 70]]  is: 1 the class is 1 acc.: True
# 904 The prediction for [[21, 43]]  is: 5 the class is 5 acc.: True
# 905 The prediction for [[54, 30]]  is: 3 the class is 3 acc.: True
# 906 The prediction for [[25, 43]]  is: 5 the class is 5 acc.: True
# 907 The prediction for [[48, 46]]  is: 5 the class is 5 acc.: True
# 908 The prediction for [[40, 60]]  is: 5 the class is 5 acc.: True
# 909 The prediction for [[20, 1]]  is: 0 the class is 0 acc.: True
# 910 The prediction for [[100, 94]]  is: 2 the class is 2 acc.: True
# 911 The prediction for [[72, 60]]  is: 1 the class is 1 acc.: True
# 912 The prediction for [[46, 18]]  is: 3 the class is 3 acc.: True
# 913 The prediction for [[100, 98]]  is: 2 the class is 2 acc.: True
# 914 The prediction for [[21, 93]]  is: 4 the class is 4 acc.: True
# 915 The prediction for [[46, 53]]  is: 5 the class is 5 acc.: True
# 916 The prediction for [[29, 59]]  is: 5 the class is 5 acc.: True
# 917 The prediction for [[60, 50]]  is: 1 the class is 1 acc.: True
# 918 The prediction for [[32, 15]]  is: 0 the class is 0 acc.: True
# 919 The prediction for [[67, 79]]  is: 4 the class is 4 acc.: True
# 920 The prediction for [[79, 53]]  is: 1 the class is 1 acc.: True
# 921 The prediction for [[69, 89]]  is: 4 the class is 4 acc.: True
# 922 The prediction for [[66, 47]]  is: 1 the class is 1 acc.: True
# 923 The prediction for [[42, 71]]  is: 4 the class is 4 acc.: True
# 924 The prediction for [[55, 59]]  is: 1 the class is 1 acc.: True
# 925 The prediction for [[51, 57]]  is: 1 the class is 1 acc.: True
# 926 The prediction for [[66, 61]]  is: 1 the class is 1 acc.: True
# 927 The prediction for [[26, 36]]  is: 5 the class is 5 acc.: True
# 928 The prediction for [[48, 37]]  is: 3 the class is 3 acc.: True
# 929 The prediction for [[36, 37]]  is: 3 the class is 3 acc.: True
# 930 The prediction for [[74, 84]]  is: 2 the class is 2 acc.: True
# 931 The prediction for [[56, 67]]  is: 1 the class is 1 acc.: True
# 932 The prediction for [[63, 58]]  is: 1 the class is 1 acc.: True
# 933 The prediction for [[59, 28]]  is: 3 the class is 3 acc.: True
# 934 The prediction for [[121, 100]]  is: 2 the class is 2 acc.: True
# 935 The prediction for [[61, 64]]  is: 1 the class is 1 acc.: True
# 936 The prediction for [[80, 40]]  is: 1 the class is 1 acc.: True
# 937 The prediction for [[44, 24]]  is: 3 the class is 3 acc.: True
# 938 The prediction for [[73, 55]]  is: 1 the class is 1 acc.: True
# 939 The prediction for [[47, 10]]  is: 3 the class is 3 acc.: True
# 940 The prediction for [[35, 28]]  is: 3 the class is 3 acc.: True
# 941 The prediction for [[10, 7]]  is: 0 the class is 0 acc.: True
# 942 The prediction for [[80, 99]]  is: 2 the class is 2 acc.: True
# 943 The prediction for [[37, 33]]  is: 3 the class is 3 acc.: True
# 944 The prediction for [[90, 67]]  is: 2 the class is 2 acc.: True
# 945 The prediction for [[22, 19]]  is: 0 the class is 0 acc.: True
# 946 The prediction for [[21, 19]]  is: 0 the class is 0 acc.: True
# 947 The prediction for [[80, 65]]  is: 1 the class is 1 acc.: True
# 948 The prediction for [[32, 14]]  is: 0 the class is 0 acc.: True
# 949 The prediction for [[61, 62]]  is: 1 the class is 1 acc.: True
# 950 The prediction for [[47, 49]]  is: 5 the class is 5 acc.: True
# 951 The prediction for [[50, 94]]  is: 4 the class is 4 acc.: True
# 952 The prediction for [[70, 68]]  is: 1 the class is 1 acc.: True
# 953 The prediction for [[37, 12]]  is: 0 the class is 0 acc.: True
# 954 The prediction for [[84, 85]]  is: 2 the class is 2 acc.: True
# 955 The prediction for [[47, 64]]  is: 5 the class is 5 acc.: True
# 956 The prediction for [[22, 10]]  is: 0 the class is 0 acc.: True
# 957 The prediction for [[104, 61]]  is: 2 the class is 2 acc.: True
# 958 The prediction for [[50, 17]]  is: 3 the class is 3 acc.: True
# 959 The prediction for [[22, 13]]  is: 0 the class is 0 acc.: True
# 960 The prediction for [[2, 5]]  is: 0 the class is 0 acc.: True
# 961 The prediction for [[27, 19]]  is: 0 the class is 0 acc.: True
# 962 The prediction for [[16, 31]]  is: 0 the class is 0 acc.: True
# 963 The prediction for [[27, 17]]  is: 0 the class is 0 acc.: True
# 964 The prediction for [[67, 58]]  is: 1 the class is 1 acc.: True
# 965 The prediction for [[39, 84]]  is: 4 the class is 4 acc.: True
# 966 The prediction for [[89, 76]]  is: 2 the class is 2 acc.: True
# 967 The prediction for [[32, 34]]  is: 3 the class is 3 acc.: True
# 968 The prediction for [[55, 22]]  is: 3 the class is 3 acc.: True
# 969 The prediction for [[71, 74]]  is: 1 the class is 1 acc.: True
# 970 The prediction for [[28, 19]]  is: 0 the class is 0 acc.: True
# 971 The prediction for [[68, 41]]  is: 1 the class is 1 acc.: True
# 972 The prediction for [[67, 89]]  is: 4 the class is 4 acc.: True
# 973 The prediction for [[79, 79]]  is: 2 the class is 2 acc.: True
# 974 The prediction for [[39, 24]]  is: 3 the class is 3 acc.: True
# 975 The prediction for [[47, 48]]  is: 5 the class is 5 acc.: True
# 976 The prediction for [[115, 88]]  is: 2 the class is 2 acc.: True
# 977 The prediction for [[79, 82]]  is: 2 the class is 2 acc.: True
# 978 The prediction for [[19, 33]]  is: 0 the class is 0 acc.: True
# 979 The prediction for [[76, 86]]  is: 2 the class is 2 acc.: True
# 980 The prediction for [[82, 82]]  is: 2 the class is 2 acc.: True
# 981 The prediction for [[23, 51]]  is: 5 the class is 5 acc.: True
# 982 The prediction for [[45, 66]]  is: 5 the class is 5 acc.: True
# 983 The prediction for [[66, 69]]  is: 1 the class is 1 acc.: True
# 984 The prediction for [[18, 69]]  is: 5 the class is 5 acc.: True
# 985 The prediction for [[25, 88]]  is: 4 the class is 4 acc.: True
# 986 The prediction for [[47, 61]]  is: 5 the class is 5 acc.: True
# 987 The prediction for [[92, 100]]  is: 2 the class is 2 acc.: True
# 988 The prediction for [[53, 24]]  is: 3 the class is 3 acc.: True
# 989 The prediction for [[24, 8]]  is: 0 the class is 0 acc.: True
# 990 The prediction for [[61, 86]]  is: 4 the class is 4 acc.: True
# 991 The prediction for [[8, 31]]  is: 0 the class is 0 acc.: True
# 992 The prediction for [[37, 11]]  is: 0 the class is 0 acc.: True
# 993 The prediction for [[57, 44]]  is: 1 the class is 1 acc.: True
# 994 The prediction for [[41, 93]]  is: 4 the class is 4 acc.: True
# 995 The prediction for [[85, 79]]  is: 2 the class is 2 acc.: True
# 996 The prediction for [[103, 100]]  is: 2 the class is 2 acc.: True
# 997 The prediction for [[71, 82]]  is: 1 the class is 4 acc.: False
# 998 The prediction for [[50, 44]]  is: 3 the class is 3 acc.: True
# 999 The prediction for [[62, 51]]  is: 1 the class is 1 acc.: True
# 1000 The prediction for [[67, 49]]  is: 1 the class is 1 acc.: True
# true: 992 false 8 accuracy 0.992

# %% [markdown]
# Random Forest

# %%
# -*- coding: utf-8 -*-
# Random Forest Classifier
# Copyright 2019 Denis Rothman MIT License. See LICENSE in GitHub directory.
import pandas as pd
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split 
from sklearn import metrics 
import pandas as pd
import numpy as np

pp=0 # print information
# load dataset
col_names = ['f1', 'f2','label']
df = pd.read_csv("ckmc.csv", header=None, names=col_names)

if pp==1:
    print(df.head())

#loading features and label (classes)
feature_cols = ['f1', 'f2']
X = df[feature_cols] # Features
y = df.label # Target variable

if pp==1:
    print(X)
    print(y)

#Divide the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

#Creatng Random Forest Classifier and  training
clf = RandomForestClassifier(n_estimators=25,random_state=None,bootstrap=True)
clf.fit(X_train, y_train)

#Predictions
y_pred = clf.predict(X_test)

if pp==1:
    print("predictions:")
    print(y_pred)

#Metrics
ae=metrics.mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:',round(ae,3))


#Double Check the Model's Accuracy
doublecheck=1  # 1=yes, 0=no
if doublecheck==1:
    t=0
    f=0
    for i in range(0,1000):
        xf1=df.at[i,'f1'];xf2=df.at[i,'f2'];xclass=df.at[i,'label']
        X_DL = [[xf1,xf2]]
        prediction =clf.predict(X_DL)
        e=False
        if(prediction==xclass):
            e=True
            t+=1
        if(prediction!=xclass):
            e=False
            f+=1
        if pp==1:
            print (i+1,"The prediction for",X_DL," is:",str(prediction).strip('[]'),"the class is",xclass,"acc.:",e)

    acc=round(t/(t+f),3)
    print("true:",t,"false",f,"accuracy",acc)
    print("Absolute Error",round(1-acc,3))
# Out:
# Mean Absolute Error: 0.095
# true: 991 false 9 accuracy 0.991
# Absolute Error 0.009
